# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# cnn model vary kernel size
from numpy import mean
from numpy import std
from numpy import dstack
from pandas import read_csv
from matplotlib import pyplot

from tensorflow.keras.utils import to_categorical
import tensorflow.keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Dropout, Flatten, Reshape, LSTM, Conv1D, MaxPooling1D, Bidirectional, ConvLSTM1D
from tensorflow.keras.layers import Input, TimeDistributed, Conv1D, MaxPooling1D, BatchNormalization, GlobalAveragePooling1D, Activation
from tensorflow.keras.layers import Input, TimeDistributed, Conv1D, MaxPooling1D, BatchNormalization, Activation, UpSampling1D
from tensorflow.keras.layers import add, multiply, GlobalAveragePooling1D
from keras import  backend as K
from tensorflow.python.keras.utils import np_utils
from sklearn.metrics import precision_score, recall_score, f1_score

from typing import Any, Dict, List, Tuple
import matplotlib.pyplot as plt
import seaborn as sns
from imblearn.over_sampling import SMOTE
from tensorflow.keras.optimizers import Adam

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns


def load_file(filepath):
    dataframe = pd.read_csv(filepath, header=None, sep='\s+')
    return dataframe.values



# load a list of files and return as a 3d numpy array
def load_group(filenames, prefix=''):
    loaded = list()
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    # stack group so that features are the 3rd dimension
    loaded = np.dstack(loaded)
    return loaded

# load a dataset group, such as train or test
def load_dataset_group(group, prefix=''):
    filepath = prefix + group + '/Inertial Signals/'
    # load all 9 files as a single array
    filenames = list()
    # total acceleration
    filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
    # body acceleration
    filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
    # body gyroscope
    filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
    # load input data
    X = load_group(filenames, filepath)
    # load class output
    y = load_file(prefix + group + '/y_'+group+'.txt')
    return X, y


# load the dataset, returns train and test X and y elements
# load the dataset, returns train and test X and y elements
def load_dataset(prefix=''):
    # load all train
    trainX, trainy = load_dataset_group('train', prefix + 'C:/Users/GACHON/Desktop/AiStudy/data/UCI HAR Dataset-20240320T080931Z-001/UCI HAR Dataset/')
    # load all test
    testX, testy = load_dataset_group('test', prefix + 'C:/Users/GACHON/Desktop/AiStudy/data/UCI HAR Dataset-20240320T080931Z-001/UCI HAR Dataset/')

    #zero-offset class values
    trainy = trainy - 1
    testy = testy - 1

    print(trainX.shape, trainy.shape, testX.shape, testy.shape)
    return trainX, trainy, testX, testy

    '''
    trainy_one_hot = to_categorical(trainy)
    testy_one_hot = to_categorical(testy)
    print(trainX.shape, trainy.shape, trainy_one_hot.shape, testX.shape, testy.shape, testy_one_hot.shape)
    return trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot
    '''

# %%
trainX, trainy, testX, testy = load_dataset()
# Out:
# (7352, 128, 9) (7352, 1) (2947, 128, 9) (2947, 1)

# %%
print(trainX)
print(trainy)
# Out:
# [[[ 1.012817e+00 -1.232167e-01  1.029341e-01 ...  3.019122e-02
#     6.601362e-02  2.285864e-02]
#   [ 1.022833e+00 -1.268756e-01  1.056872e-01 ...  4.371071e-02
#     4.269897e-02  1.031572e-02]
#   [ 1.022028e+00 -1.240037e-01  1.021025e-01 ...  3.568780e-02
#     7.485018e-02  1.324969e-02]
#   ...
#   [ 1.018445e+00 -1.240696e-01  1.003852e-01 ...  3.985177e-02
#     1.909445e-03 -2.170124e-03]
#   [ 1.019372e+00 -1.227451e-01  9.987355e-02 ...  3.744932e-02
#    -7.982483e-05 -5.642633e-03]
#   [ 1.021171e+00 -1.213260e-01  9.498741e-02 ...  2.881781e-02
#    -3.771800e-05 -1.446006e-03]]
#
#  [[ 1.018851e+00 -1.239760e-01  9.792958e-02 ...  1.711106e-02
#     6.122797e-03  1.226815e-02]
#   [ 1.022380e+00 -1.268078e-01  9.935086e-02 ...  2.417851e-02
#     9.710357e-03  1.614958e-02]
#   [ 1.020781e+00 -1.277862e-01  9.811381e-02 ...  3.022889e-02
#     1.032192e-02  1.589471e-02]
#   ...
#   [ 1.014788e+00 -1.290268e-01  9.353520e-02 ... -3.474078e-02
#    -8.694754e-03  5.044730e-03]
#   [ 1.016499e+00 -1.264244e-01  8.903516e-02 ... -3.797305e-02
#    -1.165249e-02 -4.424329e-03]
#   [ 1.017849e+00 -1.305193e-01  9.061235e-02 ... -3.864973e-02
#    -9.440197e-03 -2.797817e-03]]
#
#  [[ 1.023127e+00 -1.200157e-01  9.111667e-02 ...  2.618877e-02
#    -2.383410e-04  2.158897e-03]
#   [ 1.021882e+00 -1.214994e-01  9.267560e-02 ...  2.165149e-02
#    -4.275982e-04 -2.724752e-04]
#   [ 1.019178e+00 -1.228407e-01  9.606378e-02 ...  1.455062e-02
#     7.611350e-04  2.630986e-03]
#   ...
#   [ 1.021041e+00 -1.308757e-01  8.301135e-02 ... -2.090983e-02
#    -1.005391e-02 -5.566286e-03]
#   [ 1.022935e+00 -1.312099e-01  8.233391e-02 ... -2.211369e-02
#    -9.717281e-03 -3.701625e-03]
#   [ 1.022019e+00 -1.301826e-01  8.148748e-02 ... -2.023537e-02
#    -8.831462e-03 -2.644745e-03]]
#
#  ...
#
#  [[ 7.548917e-01 -1.711829e-01  1.745865e-01 ...  1.183561e-01
#     4.267019e-01  3.008475e-01]
#   [ 8.043137e-01 -1.999375e-01  2.324243e-01 ...  1.378901e-01
#     3.223201e-01  3.511780e-01]
#   [ 8.317140e-01 -2.319457e-01  2.576066e-01 ...  1.774201e-01
#     2.331586e-01  2.723513e-01]
#   ...
#   [ 6.956257e-01 -2.217656e-01  1.112952e-01 ... -7.609545e-01
#     6.840804e-01  2.543444e-01]
#   [ 7.479103e-01 -2.811496e-01  1.263023e-01 ... -6.779630e-01
#     6.291636e-01  2.814308e-01]
#   [ 7.767680e-01 -3.275988e-01  1.886212e-01 ... -6.275012e-01
#     4.812542e-01  2.542062e-01]]
#
#  [[ 9.279268e-01 -2.238010e-01  2.628140e-01 ... -3.788723e-01
#     1.642781e-01  2.175042e-01]
#   [ 9.129872e-01 -2.210407e-01  2.954154e-01 ... -3.738884e-01
#     6.393670e-02  1.584971e-01]
#   [ 9.246597e-01 -1.839923e-01  3.376098e-01 ... -3.301252e-01
#    -9.430612e-02  1.868787e-01]
#   ...
#   [ 6.753473e-01 -1.620087e-01  1.289247e-01 ... -4.254607e-01
#     6.504409e-01  1.762117e-01]
#   [ 6.603377e-01 -2.020367e-01  1.722512e-01 ... -4.755471e-01
#     4.097342e-01  1.635609e-01]
#   [ 7.193530e-01 -2.291273e-01  2.100712e-01 ... -4.129589e-01
#     1.998230e-01  1.887340e-01]]
#
#  [[ 7.980909e-01 -3.060512e-01  2.093865e-01 ... -4.767788e-01
#     2.889329e-01  2.277976e-01]
#   [ 8.192417e-01 -2.666046e-01  2.310711e-01 ... -2.679120e-01
#     1.712000e-01  1.034757e-01]
#   [ 8.658821e-01 -2.053607e-01  3.341906e-01 ... -1.905664e-01
#     1.424723e-01 -7.565458e-02]
#   ...
#   [ 8.980947e-01 -3.977751e-01 -1.561050e-01 ...  1.004855e+00
#     1.156645e+00 -3.625121e-01]
#   [ 8.283723e-01 -3.492473e-01 -1.227979e-01 ...  1.015589e+00
#     1.100750e+00 -3.839895e-01]
#   [ 8.002428e-01 -3.323721e-01 -8.357159e-02 ...  1.047599e+00
#     1.011324e+00 -3.358840e-01]]]
# [[4]
#  [4]
#  [4]
#  ...
#  [1]
#  [1]
#  [1]]

# %%
print("X train shape: ", trainX.shape)
print("Y train shape: ", trainy.shape)
print("X test shape: ", testX.shape)
print("Y test shape: ", testy.shape)
# Out:
# X train shape:  (7352, 128, 9)
# Y train shape:  (7352, 1)
# X test shape:  (2947, 128, 9)
# Y test shape:  (2947, 1)

# %%
print("0: Walking:" ,np.where(trainy == 0)[0].size)
print("1: WU:" ,np.where(trainy == 1)[0].size)
print("2: WD:" ,np.where(trainy == 2)[0].size)
print("3: Sitting:" ,np.where(trainy == 3)[0].size)
print("4: Standing:" ,np.where(trainy == 4)[0].size)
print("5: Laying:" ,np.where(trainy == 5)[0].size)
# Out:
# 0: Walking: 1226
# 1: WU: 1073
# 2: WD: 986
# 3: Sitting: 1286
# 4: Standing: 1374
# 5: Laying: 1407

# %%
unique, counts = np.unique(trainy, return_counts=True)
print ("Train data label statistics::")
print (np.asarray((unique, counts)).T)

unique, counts = np.unique(testy, return_counts=True)
print ("Test data label statistics::")
print (np.asarray((unique, counts)).T)
# Out:
# Train data label statistics::
# [[   0 1226]
#  [   1 1073]
#  [   2  986]
#  [   3 1286]
#  [   4 1374]
#  [   5 1407]]
# Test data label statistics::
# [[  0 496]
#  [  1 471]
#  [  2 420]
#  [  3 491]
#  [  4 532]
#  [  5 537]]

# %%
# trainy에서 값이 0, 1, 2인 행의 인덱스 찾기
indices_to_remove = np.where((trainy == 0) | (trainy == 1) | (trainy == 2))[0]

# trainX와 trainy에서 해당 인덱스를 제거하여 새로운 trainX_filtered와 trainy_filtered 얻기
trainX_filtered = np.delete(trainX, indices_to_remove, axis=0)
trainy_filtered = np.delete(trainy, indices_to_remove, axis=0)

# trainX_filtered와 trainy_filtered의 shape 확인
print("Shape of trainX_filtered:", trainX_filtered.shape)
print("Shape of trainy_filtered:", trainy_filtered.shape)
# Out:
# Shape of trainX_filtered: (4067, 128, 9)
# Shape of trainy_filtered: (4067, 1)

# %%
# trainy에서 값이 3인 것을 0으로, 값이 4인 것을 1로, 값이 5인 것을 2로 변경
trainy_filtered[trainy_filtered == 3] = 0
trainy_filtered[trainy_filtered == 4] = 1
trainy_filtered[trainy_filtered == 5] = 2

# 변경된 trainy_filtered의 값 확인
print("Modified trainy_filtered:\n", trainy_filtered)
# Out:
# Modified trainy_filtered:
#  [[1]
#  [1]
#  [1]
#  ...
#  [2]
#  [2]
#  [2]]

# %%
# trainy에서 값이 0, 1, 2인 행의 인덱스 찾기
indices_to_remove = np.where((testy == 0) | (testy == 1) | (testy == 2))[0]

# trainX와 trainy에서 해당 인덱스를 제거하여 새로운 trainX_filtered와 trainy_filtered 얻기
testX_filtered = np.delete(testX, indices_to_remove, axis=0)
testy_filtered = np.delete(testy, indices_to_remove, axis=0)

# trainX_filtered와 trainy_filtered의 shape 확인
print("Shape of testX_filtered:", testX_filtered.shape)
print("Shape of testy_filtered:", testy_filtered.shape)
# Out:
# Shape of testX_filtered: (1560, 128, 9)
# Shape of testy_filtered: (1560, 1)

# %%
# trainy에서 값이 3인 것을 0으로, 값이 4인 것을 1로, 값이 5인 것을 2로 변경
testy_filtered[testy_filtered == 3] = 0
testy_filtered[testy_filtered == 4] = 1
testy_filtered[testy_filtered == 5] = 2

# 변경된 trainy_filtered의 값 확인
print("Modified testy_filtered:\n", testy_filtered)
# Out:
# Modified testy_filtered:
#  [[1]
#  [1]
#  [1]
#  ...
#  [2]
#  [2]
#  [2]]

# %%
trainy_one_hot = to_categorical(trainy_filtered)
testy_one_hot = to_categorical(testy_filtered)
print(trainy_filtered)
print(testy_filtered)
# Out:
# [[1]
#  [1]
#  [1]
#  ...
#  [2]
#  [2]
#  [2]]
# [[1]
#  [1]
#  [1]
#  ...
#  [2]
#  [2]
#  [2]]

# %%
print("X train shape: ", trainX_filtered.shape)
print("Y train shape: ", trainy_filtered.shape)
print("Y train One hot shape: ", trainy_one_hot.shape)
print("X test shape: ", testX_filtered.shape)
print("Y test shape: ", testy_filtered.shape)
print("Y test One hot shape: ", testy_one_hot.shape)
# Out:
# X train shape:  (4067, 128, 9)
# Y train shape:  (4067, 1)
# Y train One hot shape:  (4067, 3)
# X test shape:  (1560, 128, 9)
# Y test shape:  (1560, 1)
# Y test One hot shape:  (1560, 3)

# %%
print("0: Sitting:" ,np.where(trainy_filtered == 0)[0].size)
print("1: Standing:" ,np.where(trainy_filtered == 1)[0].size)
print("2: Laying:" ,np.where(trainy_filtered == 2)[0].size)
# Out:
# 0: Sitting: 1286
# 1: Standing: 1374
# 2: Laying: 1407

# %%
unique, counts = np.unique(trainy_filtered, return_counts=True)
print ("Train data label statistics::")
print (np.asarray((unique, counts)).T)

unique, counts = np.unique(testy_filtered, return_counts=True)
print ("Test data label statistics::")
print (np.asarray((unique, counts)).T)
# Out:
# Train data label statistics::
# [[   0 1286]
#  [   1 1374]
#  [   2 1407]]
# Test data label statistics::
# [[  0 491]
#  [  1 532]
#  [  2 537]]

# %%
X_train_all = trainX_filtered   # at this stage, the data includes both dynamic and static HAR data
y_train_all = trainy_filtered

X_test_all = testX_filtered
y_test_all = testy_filtered

# %%
from sklearn.preprocessing import StandardScaler

def scale_data(trainX_filtered, testX_filtered):
 # remove overlap
 cut = int(trainX_filtered.shape[1] / 2)
 longX = trainX_filtered[:, -cut:, :]
 # flatten windows
 longX = longX.reshape((longX.shape[0] * longX.shape[1], longX.shape[2]))
 # flatten train and test
 flatTrainX = trainX_filtered.reshape((trainX_filtered.shape[0] * trainX_filtered.shape[1], trainX_filtered.shape[2]))
 flatTestX = testX_filtered.reshape((testX_filtered.shape[0] * testX_filtered.shape[1], testX_filtered.shape[2]))

 s = StandardScaler()
 # fit on training data
 s.fit(longX)
 # apply to training and test data
 longX = s.transform(longX)
 flatTrainX = s.transform(flatTrainX)
 flatTestX = s.transform(flatTestX)
 # reshape
 flatTrainX = flatTrainX.reshape((trainX_filtered.shape))
 flatTestX = flatTestX.reshape((testX_filtered.shape))
 return flatTrainX, flatTestX

# %%
trainX, testX = scale_data(trainX_filtered, testX_filtered)

# %%
print("X train shape: ", trainX_filtered.shape)
print("Y train shape: ", trainy_filtered.shape)
print("Y train One hot shape: ", trainy_one_hot.shape)
print("X test shape: ", testX_filtered.shape)
print("Y test shape: ", testy_filtered.shape)
print("Y test One hot shape: ", testy_one_hot.shape)
# Out:
# X train shape:  (4067, 128, 9)
# Y train shape:  (4067, 1)
# Y train One hot shape:  (4067, 3)
# X test shape:  (1560, 128, 9)
# Y test shape:  (1560, 1)
# Y test One hot shape:  (1560, 3)

# %%
from sklearn.model_selection import train_test_split
X_train,X_val,y_train_one_hot,y_val_one_hot,y_train,y_val=train_test_split(trainX_filtered, trainy_one_hot, trainy_filtered,test_size=0.3,random_state=100)

# %%
n_timesteps, n_features, n_outputs = trainX_filtered.shape[1], trainX_filtered.shape[2], trainy_one_hot.shape[1]

# %%
def conv_block(in_x, nb_filter, kernel_size):

    x = Conv1D(nb_filter, kernel_size, padding='same')(in_x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

# %%
def convolutional_block(in_x, nb_filters, stride):

    F1, F2, F3 = nb_filters

    x = in_x

    x = Conv1D(F1, 3, strides=stride,  padding='same', kernel_initializer="he_normal")(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv1D(F2, 3, strides=1, padding='same', kernel_initializer="he_normal")(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv1D(F3, 1, strides=1, padding='same', kernel_initializer="he_normal")(x)
    x = BatchNormalization()(x)

    x1 = Conv1D(F3, 1, strides=stride, padding='same', kernel_initializer="he_normal")(in_x)
    x1 = BatchNormalization()(x1)

    x = add([x, x1])
    x = Activation('relu')(x)

    return x

# %%
def attention_branch(in_x, nb_filter, kernel_size):

    x1 = conv_block(in_x, nb_filter, kernel_size)

    x = MaxPooling1D(2)(x1)
    x = conv_block(x, nb_filter, kernel_size)
    x = UpSampling1D(size = 2)(x)

    x2 = conv_block(x, nb_filter, kernel_size)

    if(K.int_shape(x1)!=K.int_shape(x2)):
        x2 = ZeroPadding1D(1)(x2)
        x2 = Cropping1D((1,0))(x2)

    x = add([x1, x2])

    x = conv_block(x, nb_filter, kernel_size)

    x = Conv1D(nb_filter, 1, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('sigmoid')(x)

    return x

# %%
#Residual-Based Temporal Attention Block

def RTA_block(in_x, nb_filter, kernel_size):

    x1 = conv_block(in_x, nb_filter, kernel_size)
    x2 = conv_block(x1, nb_filter, kernel_size)

    attention_map = attention_branch(x1, nb_filter, kernel_size)

    x = multiply([x2, attention_map])
    x = add([x, x1])

    out = conv_block(x, nb_filter, kernel_size)

    return out

# %%
def RTA_CNN():

    inputs = Input(shape=(n_timesteps,n_features))

    x = RTA_block(inputs, 16, 32)
    x = MaxPooling1D(4)(x)

    x = RTA_block(x, 32, 16)
    x = MaxPooling1D(4)(x)

    x = RTA_block(x, 64, 9)
    x = MaxPooling1D(2)(x)
    x = RTA_block(x, 64, 9)
    x = MaxPooling1D(2)(x)
    x = Dropout(0.6)(x)

    x = RTA_block(x, 128, 3)
    x = MaxPooling1D(2)(x)
    x = RTA_block(x, 128, 3)
    x = MaxPooling1D(2)(x)
    x = Dropout(0.6)(x)

    x = Flatten()(x)
    x = Dropout(0.7)(x)
    x = Dense(100,  activation='relu')(x)
    x = Dropout(0.7)(x)
    x = Dense(n_outputs,  activation='softmax')(x)

    model = Model(inputs, x)

    return model

# %%
def se_block(in_x, nb_filter):
        squeeze = GlobalAveragePooling1D()(in_x)
        excitation = Dense(units=nb_filter // 2)(squeeze)
        excitation = Activation('relu')(excitation)
        excitation = Dense(units=nb_filter)(excitation)
        excitation = Activation('sigmoid')(excitation)
        excitation = Reshape((1,nb_filter))(excitation)
        scale = multiply([in_x,excitation])
        out = add([in_x, scale])

        return out

# %%
def SENET():

    inputs = Input(shape=(n_timesteps, n_features))

    x = LSTM(16, return_sequences=True)(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = se_block(x, 16)
    x = MaxPooling1D(4)(x)

    x = LSTM(32, return_sequences=True)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = se_block(x, 32)
    x = MaxPooling1D(4)(x)

    x = LSTM(64, return_sequences=True)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = se_block(x, 64)
    x = MaxPooling1D(2)(x)

    x = LSTM(64, return_sequences=True)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = se_block(x, 64)
    x = MaxPooling1D(2)(x)

    x = LSTM(128, return_sequences=True)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = se_block(x, 128)
    x = MaxPooling1D(2)(x)

    x = LSTM(128, return_sequences=True)(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = se_block(x, 128)

    x = Flatten()(x)
    x = Dense(300, activation='relu')(x)
    x = Dense(n_outputs, activation='softmax')(x)

    model = Model(inputs, x)

    return model

# %%
def RESNET50():

    inputs = Input(shape=(n_timesteps,n_features))

    filter_num = 64

    x = Conv1D(filter_num, 3, strides=2, kernel_initializer="he_normal")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = MaxPooling1D(3, stride=2)(x)

    x = convolutional_block(x, [filter_num, filter_num, filter_num * 4], 4)
    x = identity_block(x, [filter_num, filter_num, filter_num * 4])
    x = identity_block(x, [filter_num, filter_num, filter_num * 4])

    x = convolutional_block(x, [filter_num * 2, filter_num * 2, filter_num * 8], 4)
    x = identity_block(x, [filter_num * 2, filter_num * 2, filter_num * 8])
    x = identity_block(x, [filter_num * 2, filter_num * 2, filter_num * 8])
    x = identity_block(x, [filter_num * 2, filter_num * 2, filter_num * 8])

    x = convolutional_block(x, [filter_num * 4, filter_num * 4, filter_num * 16], 2)
    x = identity_block(x, [filter_num * 4, filter_num * 4, filter_num * 16])
    x = identity_block(x, [filter_num * 4, filter_num * 4, filter_num * 16])
    x = identity_block(x, [filter_num * 4, filter_num * 4, filter_num * 16])
    x = identity_block(x, [filter_num * 4, filter_num * 4, filter_num * 16])
    x = identity_block(x, [filter_num * 4, filter_num * 4, filter_num * 16])

    x = convolutional_block(x, [filter_num * 8, filter_num * 8, filter_num * 32], 2)
    x = identity_block(x, [filter_num * 8, filter_num * 8, filter_num * 32])
    x = identity_block(x, [filter_num * 8, filter_num * 8, filter_num * 32])

    x = GlobalAveragePooling1D()(x)
    x = Dense(500, activation="relu", kernel_initializer="he_normal")(x)
    x = Dense(n_outputs, activation="softmax")(x)

    model = Model(inputs, x)

    return model

# %%
import math

def en_loss(y_true, y_pred):

    epsilon = 1.e-7
    gamma = float(0.3)

    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.clip_by_value(y_pred, epsilon, 1. - epsilon)
    pos_pred = tf.pow(-tf.math.log(y_pred),gamma)
    nag_pred = tf.pow(-tf.math.log(1-y_pred),gamma)
    y_t = tf.multiply(y_true, pos_pred) + tf.multiply(1-y_true, nag_pred)
    en_loss = tf.reduce_mean(y_t)
    return en_loss

# %% [markdown]
# ## SEblock

# %%
from keras.models import Model
model = SENET()
model.summary()
optimizer = Adam(learning_rate=1e-4)
model.compile(optimizer = optimizer, loss=en_loss, metrics = ["accuracy"])

checkpoint_cb = keras.callbacks.ModelCheckpoint('best-lstm-model.h5',
                                                save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=5,
                                                  restore_best_weights=True)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 9)]     0           []
#
#  lstm (LSTM)                    (None, 128, 16)      1664        ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 128, 16)     64          ['lstm[0][0]']
#  alization)
#
#  activation (Activation)        (None, 128, 16)      0           ['batch_normalization[0][0]']
#
#  global_average_pooling1d (Glob  (None, 16)          0           ['activation[0][0]']
#  alAveragePooling1D)
#
#  dense (Dense)                  (None, 8)            136         ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  activation_1 (Activation)      (None, 8)            0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 16)           144         ['activation_1[0][0]']
#
#  activation_2 (Activation)      (None, 16)           0           ['dense_1[0][0]']
#
#  reshape (Reshape)              (None, 1, 16)        0           ['activation_2[0][0]']
#
#  multiply (Multiply)            (None, 128, 16)      0           ['activation[0][0]',
#                                                                   'reshape[0][0]']
#
#  add (Add)                      (None, 128, 16)      0           ['activation[0][0]',
#                                                                   'multiply[0][0]']
#
#  max_pooling1d (MaxPooling1D)   (None, 32, 16)       0           ['add[0][0]']
#
#  lstm_1 (LSTM)                  (None, 32, 32)       6272        ['max_pooling1d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 32, 32)      128         ['lstm_1[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 32, 32)       0           ['batch_normalization_1[0][0]']
#
#  global_average_pooling1d_1 (Gl  (None, 32)          0           ['activation_3[0][0]']
#  obalAveragePooling1D)
#
#  dense_2 (Dense)                (None, 16)           528         ['global_average_pooling1d_1[0][0
#                                                                  ]']
#
#  activation_4 (Activation)      (None, 16)           0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 32)           544         ['activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 32)           0           ['dense_3[0][0]']
#
#  reshape_1 (Reshape)            (None, 1, 32)        0           ['activation_5[0][0]']
#
#  multiply_1 (Multiply)          (None, 32, 32)       0           ['activation_3[0][0]',
#                                                                   'reshape_1[0][0]']
#
#  add_1 (Add)                    (None, 32, 32)       0           ['activation_3[0][0]',
#                                                                   'multiply_1[0][0]']
#
#  max_pooling1d_1 (MaxPooling1D)  (None, 8, 32)       0           ['add_1[0][0]']
#
#  lstm_2 (LSTM)                  (None, 8, 64)        24832       ['max_pooling1d_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 8, 64)       256         ['lstm_2[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 8, 64)        0           ['batch_normalization_2[0][0]']
#
#  global_average_pooling1d_2 (Gl  (None, 64)          0           ['activation_6[0][0]']
#  obalAveragePooling1D)
#
#  dense_4 (Dense)                (None, 32)           2080        ['global_average_pooling1d_2[0][0
#                                                                  ]']
#
#  activation_7 (Activation)      (None, 32)           0           ['dense_4[0][0]']
#
#  dense_5 (Dense)                (None, 64)           2112        ['activation_7[0][0]']
#
#  activation_8 (Activation)      (None, 64)           0           ['dense_5[0][0]']
#
#  reshape_2 (Reshape)            (None, 1, 64)        0           ['activation_8[0][0]']
#
#  multiply_2 (Multiply)          (None, 8, 64)        0           ['activation_6[0][0]',
#                                                                   'reshape_2[0][0]']
#
#  add_2 (Add)                    (None, 8, 64)        0           ['activation_6[0][0]',
#                                                                   'multiply_2[0][0]']
#
#  max_pooling1d_2 (MaxPooling1D)  (None, 4, 64)       0           ['add_2[0][0]']
#
#  lstm_3 (LSTM)                  (None, 4, 64)        33024       ['max_pooling1d_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 4, 64)       256         ['lstm_3[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 4, 64)        0           ['batch_normalization_3[0][0]']
#
#  global_average_pooling1d_3 (Gl  (None, 64)          0           ['activation_9[0][0]']
#  obalAveragePooling1D)
#
#  dense_6 (Dense)                (None, 32)           2080        ['global_average_pooling1d_3[0][0
#                                                                  ]']
#
#  activation_10 (Activation)     (None, 32)           0           ['dense_6[0][0]']
#
#  dense_7 (Dense)                (None, 64)           2112        ['activation_10[0][0]']
#
#  activation_11 (Activation)     (None, 64)           0           ['dense_7[0][0]']
#
#  reshape_3 (Reshape)            (None, 1, 64)        0           ['activation_11[0][0]']
#
#  multiply_3 (Multiply)          (None, 4, 64)        0           ['activation_9[0][0]',
#                                                                   'reshape_3[0][0]']
#
#  add_3 (Add)                    (None, 4, 64)        0           ['activation_9[0][0]',
#                                                                   'multiply_3[0][0]']
#
#  max_pooling1d_3 (MaxPooling1D)  (None, 2, 64)       0           ['add_3[0][0]']
#
#  lstm_4 (LSTM)                  (None, 2, 128)       98816       ['max_pooling1d_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 2, 128)      512         ['lstm_4[0][0]']
#  rmalization)
#
#  activation_12 (Activation)     (None, 2, 128)       0           ['batch_normalization_4[0][0]']
#
#  global_average_pooling1d_4 (Gl  (None, 128)         0           ['activation_12[0][0]']
#  obalAveragePooling1D)
#
#  dense_8 (Dense)                (None, 64)           8256        ['global_average_pooling1d_4[0][0
#                                                                  ]']
#
#  activation_13 (Activation)     (None, 64)           0           ['dense_8[0][0]']
#
#  dense_9 (Dense)                (None, 128)          8320        ['activation_13[0][0]']
#
#  activation_14 (Activation)     (None, 128)          0           ['dense_9[0][0]']
#
#  reshape_4 (Reshape)            (None, 1, 128)       0           ['activation_14[0][0]']
#
#  multiply_4 (Multiply)          (None, 2, 128)       0           ['activation_12[0][0]',
#                                                                   'reshape_4[0][0]']
#
#  add_4 (Add)                    (None, 2, 128)       0           ['activation_12[0][0]',
#                                                                   'multiply_4[0][0]']
#
#  max_pooling1d_4 (MaxPooling1D)  (None, 1, 128)      0           ['add_4[0][0]']
#
#  lstm_5 (LSTM)                  (None, 1, 128)       131584      ['max_pooling1d_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 1, 128)      512         ['lstm_5[0][0]']
#  rmalization)
#
#  activation_15 (Activation)     (None, 1, 128)       0           ['batch_normalization_5[0][0]']
#
#  global_average_pooling1d_5 (Gl  (None, 128)         0           ['activation_15[0][0]']
#  obalAveragePooling1D)
#
#  dense_10 (Dense)               (None, 64)           8256        ['global_average_pooling1d_5[0][0
#                                                                  ]']
#
#  activation_16 (Activation)     (None, 64)           0           ['dense_10[0][0]']
#
#  dense_11 (Dense)               (None, 128)          8320        ['activation_16[0][0]']
#
#  activation_17 (Activation)     (None, 128)          0           ['dense_11[0][0]']
#
#  reshape_5 (Reshape)            (None, 1, 128)       0           ['activation_17[0][0]']
#
#  multiply_5 (Multiply)          (None, 1, 128)       0           ['activation_15[0][0]',
#                                                                   'reshape_5[0][0]']
#
#  add_5 (Add)                    (None, 1, 128)       0           ['activation_15[0][0]',
#                                                                   'multiply_5[0][0]']
#
#  flatten (Flatten)              (None, 128)          0           ['add_5[0][0]']
#
#  dense_12 (Dense)               (None, 300)          38700       ['flatten[0][0]']
#
#  dense_13 (Dense)               (None, 3)            903         ['dense_12[0][0]']
#
# ==================================================================================================
# Total params: 380,411
# Trainable params: 379,547
# Non-trainable params: 864
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
# validation_split = 0.1
batch_size = 128

train_epochs = 30
history = model.fit(trainX_filtered, trainy_one_hot, epochs=train_epochs, batch_size=batch_size, verbose=True,
                    validation_data = (X_val, y_val_one_hot), callbacks=[checkpoint_cb, early_stopping_cb], shuffle=True)
# Out:
# Epoch 1/30
# 32/32 [==============================] - 8s 67ms/step - loss: 0.6457 - accuracy: 0.7099 - val_loss: 0.8511 - val_accuracy: 0.3767
# Epoch 2/30
# 32/32 [==============================] - 1s 28ms/step - loss: 0.3287 - accuracy: 0.8896 - val_loss: 0.8507 - val_accuracy: 0.3767
# Epoch 3/30
# 32/32 [==============================] - 1s 27ms/step - loss: 0.2043 - accuracy: 0.9075 - val_loss: 0.8501 - val_accuracy: 0.3767
# Epoch 4/30
# 32/32 [==============================] - 1s 27ms/step - loss: 0.1588 - accuracy: 0.9125 - val_loss: 0.8490 - val_accuracy: 0.3767
# Epoch 5/30
# 32/32 [==============================] - 1s 27ms/step - loss: 0.1341 - accuracy: 0.9189 - val_loss: 0.8472 - val_accuracy: 0.3767
# Epoch 6/30
# 32/32 [==============================] - 1s 27ms/step - loss: 0.1262 - accuracy: 0.9194 - val_loss: 0.8438 - val_accuracy: 0.3767
# Epoch 7/30
# 32/32 [==============================] - 1s 27ms/step - loss: 0.1170 - accuracy: 0.9260 - val_loss: 0.8349 - val_accuracy: 0.3964
# Epoch 8/30
# 32/32 [==============================] - 1s 25ms/step - loss: 0.1074 - accuracy: 0.9292 - val_loss: 0.8139 - val_accuracy: 0.7396
# Epoch 9/30
# 32/32 [==============================] - 1s 26ms/step - loss: 0.1063 - accuracy: 0.9336 - val_loss: 0.7768 - val_accuracy: 0.8542
# Epoch 10/30
# 32/32 [==============================] - 1s 26ms/step - loss: 0.0981 - accuracy: 0.9361 - val_loss: 0.6996 - val_accuracy: 0.8616
# Epoch 11/30
# 32/32 [==============================] - 1s 26ms/step - loss: 0.0933 - accuracy: 0.9410 - val_loss: 0.5828 - val_accuracy: 0.8149
# Epoch 12/30
# 32/32 [==============================] - 1s 27ms/step - loss: 0.0961 - accuracy: 0.9400 - val_loss: 0.4386 - val_accuracy: 0.8747
# Epoch 13/30
# 32/32 [==============================] - 1s 26ms/step - loss: 0.0900 - accuracy: 0.9417 - val_loss: 0.3214 - val_accuracy: 0.8796
# Epoch 14/30
# 32/32 [==============================] - 1s 27ms/step - loss: 0.0886 - accuracy: 0.9430 - val_loss: 0.2402 - val_accuracy: 0.8968
# Epoch 15/30
# 32/32 [==============================] - 1s 26ms/step - loss: 0.0871 - accuracy: 0.9447 - val_loss: 0.1778 - val_accuracy: 0.9165
# Epoch 16/30
# 32/32 [==============================] - 1s 26ms/step - loss: 0.0833 - accuracy: 0.9466 - val_loss: 0.1445 - val_accuracy: 0.9255
# Epoch 17/30
# 32/32 [==============================] - 1s 26ms/step - loss: 0.0855 - accuracy: 0.9447 - val_loss: 0.1181 - val_accuracy: 0.9337
# Epoch 18/30
# 32/32 [==============================] - 1s 26ms/step - loss: 0.0849 - accuracy: 0.9457 - val_loss: 0.0923 - val_accuracy: 0.9500
# Epoch 19/30
# 32/32 [==============================] - 1s 26ms/step - loss: 0.0780 - accuracy: 0.9516 - val_loss: 0.0886 - val_accuracy: 0.9525
# Epoch 20/30
# 32/32 [==============================] - 1s 26ms/step - loss: 0.0823 - accuracy: 0.9474 - val_loss: 0.0784 - val_accuracy: 0.9566
# Epoch 21/30
# 32/32 [==============================] - 1s 24ms/step - loss: 0.0766 - accuracy: 0.9501 - val_loss: 0.0882 - val_accuracy: 0.9459
# Epoch 22/30
# 32/32 [==============================] - 1s 26ms/step - loss: 0.0773 - accuracy: 0.9486 - val_loss: 0.0590 - val_accuracy: 0.9623
# Epoch 23/30
# 32/32 [==============================] - 1s 26ms/step - loss: 0.0705 - accuracy: 0.9562 - val_loss: 0.0529 - val_accuracy: 0.9713
# Epoch 24/30
# 32/32 [==============================] - 1s 26ms/step - loss: 0.0780 - accuracy: 0.9528 - val_loss: 0.0489 - val_accuracy: 0.9722
# Epoch 25/30
# 32/32 [==============================] - 1s 24ms/step - loss: 0.0662 - accuracy: 0.9594 - val_loss: 0.0508 - val_accuracy: 0.9705
# Epoch 26/30
# 32/32 [==============================] - 1s 26ms/step - loss: 0.0671 - accuracy: 0.9577 - val_loss: 0.0450 - val_accuracy: 0.9754
# Epoch 27/30
# 32/32 [==============================] - 1s 24ms/step - loss: 0.0694 - accuracy: 0.9560 - val_loss: 0.0555 - val_accuracy: 0.9623
# Epoch 28/30
# 32/32 [==============================] - 1s 25ms/step - loss: 0.0692 - accuracy: 0.9555 - val_loss: 0.0506 - val_accuracy: 0.9672
# Epoch 29/30
# 32/32 [==============================] - 1s 24ms/step - loss: 0.0729 - accuracy: 0.9543 - val_loss: 0.0499 - val_accuracy: 0.9689
# Epoch 30/30
# 32/32 [==============================] - 1s 23ms/step - loss: 0.0724 - accuracy: 0.9550 - val_loss: 0.0481 - val_accuracy: 0.9705

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Training and validation accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

predy=model.predict(testX_filtered)
predy=np.argmax(predy, axis=-1)
LABELS = ['SITTING','STANDIND','LAYING']
cm=confusion_matrix(testy_filtered,predy)
print(cm)
print(accuracy_score(testy_filtered,predy))
print(f1_score(testy_filtered,predy, average='weighted'))
print(classification_report(testy_filtered,predy))
sns.heatmap(cm, cmap="YlGnBu", xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt = '.2f')
# Out:
# 49/49 [==============================] - 2s 10ms/step
# [[394  97   0]
#  [ 56 475   1]
#  [  0   0 537]]
# 0.9012820512820513
# 0.9009340794692003
#               precision    recall  f1-score   support
#
#            0       0.88      0.80      0.84       491
#            1       0.83      0.89      0.86       532
#            2       1.00      1.00      1.00       537
#
#     accuracy                           0.90      1560
#    macro avg       0.90      0.90      0.90      1560
# weighted avg       0.90      0.90      0.90      1560
# <Axes: >
