# %% [markdown]
# 이 데이터 세트는 비침습적 혈압 예측에 사용되는 MIMIC-III 데이터 세트의 하위 집합입니다. PPG 및 ABP 데이터는 7초 길이의 윈도우(875개 데이터 포인트)로 나뉩니다. 수축기 및 이완기 혈압 값은 ABP 윈도우에서 파생되었습니다. 데이터 세트의 각 샘플은 PPG 신호와 혈압 값, 그리고 고유한 피험자 식별자로 구성됩니다. 이 파일은 세 개의 데이터 세트로 구성됩니다.
#
# PPG: 905,400 x 875 크기의 PPG 데이터
# 레이블: 905,400 x 2 크기의 BP 데이터
# subject_idx: 각 샘플의 피험자 소속(크기 905,400 x 1)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, Input, Model

# cnn model vary kernel size
from numpy import mean
from numpy import std
from numpy import dstack
from pandas import read_csv
from matplotlib import pyplot

from tensorflow.keras.utils import to_categorical
import tensorflow.keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Dropout, Flatten, Reshape, LSTM, Conv1D, MaxPooling1D, Bidirectional, ConvLSTM1D, GRU
from tensorflow.keras.layers import Input, TimeDistributed, Conv1D, MaxPooling1D, BatchNormalization, GlobalAveragePooling1D, Activation, UpSampling1D
from tensorflow.python.keras.utils import np_utils
from sklearn.metrics import precision_score, recall_score, f1_score
from tensorflow.keras.layers import add, multiply, GlobalAveragePooling1D
from sklearn.linear_model import LinearRegression

from typing import Any, Dict, List, Tuple
import matplotlib.pyplot as plt
import seaborn as sns
from keras import  backend as K
import numpy as np
import pandas as pd
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# 2024-08-17 14:39:17.811959: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9360] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-17 14:39:17.812018: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-17 14:39:17.812046: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1537] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-17 14:39:17.820440: I tensorflow/core/platform/cpu_feature_guard.cc:183] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import h5py

# 잠금 없이 파일 열기
with h5py.File('MIMIC-III_ppg_dataset.h5', 'r', locking=False) as f:
    dataset_names = list(f.keys())
    print("Available datasets:", dataset_names)
# Out:
# Available datasets: ['label', 'ppg', 'subject_idx']

# %%
# .h5 파일 열기
with h5py.File('MIMIC-III_ppg_dataset.h5', 'r', locking=False) as f:
    # 특정 데이터셋 불러오기 (예: 'label' 데이터셋)
    data_label = f['label'][:]
    data_ppg = f['ppg'][:]
    data_subject_idx = f['subject_idx'][:]
    
    print(data_label)
    print(data_ppg)
    print(data_subject_idx)
# Out:
# [[ 98  57]
#  [100  56]
#  [115  60]
#  ...
#  [143  66]
#  [119  63]
#  [146  74]]
# [[-0.5025518  -0.5326032  -0.5624843  ... -0.28123745 -0.27767116
#   -0.2727553 ]
#  [-0.32402784 -0.3677722  -0.41105923 ...  0.660843    0.5616221
#    0.4570674 ]
#  [ 0.0789502  -0.02330504 -0.12383569 ... -0.04361962 -0.03981035
#   -0.03410682]
#  ...
#  [-0.22356206 -0.27264422 -0.32297283 ... -0.0673175  -0.06447504
#   -0.06026017]
#  [-0.03491007 -0.1202258  -0.20588434 ...  0.28017786  0.28330782
#    0.2905485 ]
#  [ 0.38536417  0.43365255  0.48704892 ... -0.30071005 -0.29895812
#   -0.2964506 ]]
# [[   0]
#  [   0]
#  [   0]
#  ...
#  [4554]
#  [4554]
#  [4554]]

# %%
print(data_label.shape)
print(data_ppg.shape)
print(data_subject_idx)
# Out:
# (9054000, 2)
# (9054000, 875)
# [[   0]
#  [   0]
#  [   0]
#  ...
#  [4554]
#  [4554]
#  [4554]]

# %% [markdown]
# data_label 값 중 앞부분은 수축기 혈압(SBP), 뒷 부분은 이완기 혈압(DBP)

# %%
# 각각의 데이터를 DataFrame으로 변환
df_label = pd.DataFrame(data_label, columns=['SBP', 'DBP'])
df_ppg = pd.DataFrame(data_ppg)
df_subject_idx = pd.DataFrame(data_subject_idx, columns=['subject_idx'])

# %%
# 세 개의 DataFrame을 하나로 합치기
df = pd.concat([df_subject_idx, df_label, df_ppg], axis=1)

# 결과 확인
print(df.head())
# Out:
#    subject_idx  SBP  DBP         0         1         2         3         4  \
# 0            0   98   57 -0.502552 -0.532603 -0.562484 -0.591756 -0.620017
# 1            0  100   56 -0.324028 -0.367772 -0.411059 -0.453427 -0.494457
# 2            0  115   60  0.078950 -0.023305 -0.123836 -0.221000 -0.313295
# 3            0   83   55  0.233394  0.251590  0.267639  0.279521  0.285665
# 4            0  109   58 -0.173036 -0.190641 -0.208551 -0.226650 -0.244931
#
#           5         6  ...       865       866       867       868       869  \
# 0 -0.646934 -0.672269  ... -0.257694 -0.267066 -0.274259 -0.279373 -0.282512
# 1 -0.533794 -0.571164  ...  1.077976  1.055641  1.019408  0.970138  0.908652
# 2 -0.399417 -0.478317  ... -0.012682 -0.025805 -0.034969 -0.040991 -0.044514
# 3  0.285092  0.277481  ... -0.217937 -0.226153 -0.233065 -0.238201 -0.241181
# 4 -0.263568 -0.282928  ... -0.305273 -0.304013 -0.303961 -0.304851 -0.306394
#
#         870       871       872       873       874
# 0 -0.283788 -0.283321 -0.281237 -0.277671 -0.272755
# 1  0.835847  0.752798  0.660843  0.561622  0.457067
# 2 -0.045987 -0.045662 -0.043620 -0.039810 -0.034107
# 3 -0.241780 -0.239970 -0.235934 -0.230042 -0.222807
# 4 -0.308315 -0.310368 -0.312341 -0.314045 -0.315297
#
# [5 rows x 878 columns]

# %%
# 슬라이싱을 통해 상위 5만 개의 rows 선택
df = df[:20000]

# %%
'''# 데이터 샘플링 (예: 10%)
df_sample = df.sample(frac=0.1, random_state=42)

# 특징과 타겟 설정
features = df_sample.drop(['subject_idx', 'SBP', 'DBP'], axis=1)
target_sbp = df_sample['SBP']
target_dbp = df_sample['DBP']
'''
# Out:
# "# 데이터 샘플링 (예: 10%)\ndf_sample = df.sample(frac=0.1, random_state=42)\n\n# 특징과 타겟 설정\nfeatures = df_sample.drop(['subject_idx', 'SBP', 'DBP'], axis=1)\ntarget_sbp = df_sample['SBP']\ntarget_dbp = df_sample['DBP']\n"

# %%
# 특징(features)과 타겟(target) 변수 설정
features = df.drop(['subject_idx', 'SBP', 'DBP'], axis=1)  # 'subject_idx', 'SBP', 'DBP'를 제외한 나머지가 특징
target_sbp = df['SBP']  # SBP 예측
target_dbp = df['DBP']  # DBP 예측

# %%
from scipy import stats

def create_dataset(X, y, time_steps=1, step=1):
    Xs, ys = [], []
    for i in range(0, len(X) - time_steps, step):
        v = X.iloc[i:(i + time_steps)].values
        labels = y.iloc[i: i + time_steps]
        Xs.append(v)
        ys.append(stats.mode(labels)[0])
    return np.array(Xs), np.array(ys).reshape(-1, 1)

# %%
TIME_STEPS = 200
STEP = 40

# %%
X_sbp, y_sbp = create_dataset(features, target_sbp, TIME_STEPS,STEP)
X_dbp, y_dbp = create_dataset(features, target_dbp, TIME_STEPS,STEP)

# %%
# 학습 데이터와 테스트 데이터로 분리
from sklearn.model_selection import train_test_split
X_train_sbp, X_test_sbp, y_train_sbp, y_test_sbp = train_test_split(X_sbp, y_sbp, test_size=0.2, random_state=42)
X_train_dbp, X_test_dbp, y_train_dbp, y_test_dbp = train_test_split(X_dbp, y_dbp, test_size=0.2, random_state=42)

# %%
X_train_sbp, X_val_sbp, y_train_sbp, y_val_sbp = train_test_split(X_train_sbp, y_train_sbp, test_size=0.2, random_state=42)
X_train_dbp, X_val_dbp, y_train_dbp, y_val_dbp = train_test_split(X_train_dbp, y_train_dbp, test_size=0.2, random_state=42)

# %%
print(X_train_sbp)
print(y_train_sbp)
print(X_train_sbp.shape)
print(y_train_sbp.shape)
# Out:
# [[[-0.08734079  0.14538272  0.37616134 ... -0.30338317 -0.30026004
#    -0.29651207]
#   [-0.13399865 -0.15464634 -0.17522067 ...  0.347568    0.25832617
#     0.16656649]
#   [-0.06255069  0.17568322  0.40280938 ... -0.24734193 -0.15508166
#    -0.0672254 ]
#   ...
#   [-0.03528887 -0.06097228 -0.08514317 ... -0.305176   -0.26782784
#    -0.2275739 ]
#   [ 0.01653224  0.15638548  0.30133954 ...  0.40812045  0.21469696
#     0.01111817]
#   [ 0.3191376   0.3829499   0.4549099  ... -0.6957228  -0.4991984
#    -0.29387897]]
#
#  [[ 0.19069411  0.06652807 -0.05708411 ...  0.3940342   0.35005113
#     0.30836785]
#   [ 0.2566164   0.23312461  0.20953959 ... -0.05851342 -0.07184143
#    -0.08243753]
#   [-0.4881514  -0.58252937 -0.67660105 ... -0.04621337 -0.05946529
#    -0.07034957]
#   ...
#   [-0.16160634 -0.00217425  0.14916842 ...  0.4995185   0.43106964
#     0.3618249 ]
#   [ 0.23093337  0.14490356  0.06098947 ... -0.5001771  -0.33043694
#    -0.1510811 ]
#   [ 0.0687525  -0.0395284  -0.14987448 ... -0.15087934 -0.12727891
#    -0.09874338]]
#
#  [[ 0.33116147  0.44564095  0.55928254 ...  0.17434174  0.16304266
#     0.15228592]
#   [-0.15199018 -0.17873643 -0.20542774 ... -0.13683313 -0.12443984
#    -0.11192595]
#   [ 0.2529055   0.35227445  0.44707546 ... -0.2156803  -0.20422156
#    -0.19135028]
#   ...
#   [-0.44426042 -0.48392045 -0.5235524  ...  0.14868756  0.12844324
#     0.11009612]
#   [-0.30862793 -0.34194726 -0.3762974  ...  0.04832112  0.03653631
#     0.02659033]
#   [-0.5441993  -0.5371754  -0.5326079  ...  0.20011356  0.16410108
#     0.12843512]]
#
#  ...
#
#  [[-0.21899265 -0.28481486 -0.34848458 ...  0.16383731  0.09494627
#     0.02202337]
#   [ 0.22293295  0.36456674  0.50124156 ...  0.82717675  0.67779386
#     0.5223675 ]
#   [-0.40390185 -0.51505375 -0.6249834  ... -0.38623106 -0.3076674
#    -0.23334326]
#   ...
#   [ 0.04102055  0.13755876  0.23421621 ...  0.44698548  0.36227784
#     0.27656227]
#   [-0.38349324 -0.48712605 -0.5921756  ...  0.49779946  0.3927032
#     0.28466126]
#   [ 0.03965467  0.0232018   0.00880425 ...  0.34000686  0.31388062
#     0.28669924]]
#
#  [[ 0.1286859   0.3293149   0.52956396 ...  0.00455542 -0.071462
#    -0.15926476]
#   [-0.15063548  0.07637948  0.29688296 ... -0.34529236 -0.26760873
#    -0.19668141]
#   [-0.0077583   0.16715021  0.34422022 ... -0.30678654 -0.283866
#    -0.2578434 ]
#   ...
#   [-0.10848857 -0.08506657 -0.06289789 ...  0.29125816  0.227415
#     0.15489615]
#   [ 0.24487868  0.33139583  0.42891338 ... -0.29420853 -0.2702991
#    -0.24276848]
#   [-0.09815387  0.04548691  0.19263743 ... -0.2524222  -0.21005647
#    -0.17729674]]
#
#  [[ 0.09305917  0.17944841  0.2650283  ... -0.2568641  -0.06117639
#     0.12481891]
#   [ 0.5039318   0.39417017  0.29218343 ... -0.28074968 -0.17020927
#    -0.06584038]
#   [-0.27230948 -0.24893714 -0.22640179 ... -0.29734147 -0.26890942
#    -0.24014358]
#   ...
#   [ 0.03617437  0.01330202 -0.01047686 ... -0.11194738 -0.07785478
#    -0.05628133]
#   [ 0.39060575  0.36092016  0.34275472 ...  0.35302606  0.3288929
#     0.3102382 ]
#   [-0.19360895 -0.24548212 -0.29582903 ...  0.71494097  0.581475
#     0.44891724]]]
# [[ 89]
#  [ 88]
#  [133]
#  [122]
#  [ 86]
#  [103]
#  [121]
#  [124]
#  [122]
#  [150]
#  [121]
#  [107]
#  [125]
#  [ 90]
#  [140]
#  [136]
#  [ 90]
#  [101]
#  [140]
#  [125]
#  [107]
#  [121]
#  [128]
#  [124]
#  [ 97]
#  [154]
#  [127]
#  [106]
#  [121]
#  [ 94]
#  [121]
#  [135]
#  [120]
#  [121]
#  [106]
#  [103]
#  [139]
#  [ 76]
#  [128]
#  [125]
#  [107]
#  [ 84]
#  [123]
#  [144]
#  [ 95]
#  [125]
#  [ 99]
#  [125]
#  [133]
#  [ 98]
#  [140]
#  [121]
#  [ 86]
#  [ 95]
#  [121]
#  [126]
#  [ 88]
#  [100]
#  [116]
#  [106]
#  [124]
#  [105]
#  [107]
#  [137]
#  [ 97]
#  [121]
#  [100]
#  [128]
#  [127]
#  [143]
#  [138]
#  [121]
#  [124]
#  [133]
#  [ 94]
#  [107]
#  [106]
#  [128]
#  [122]
#  [125]
#  [105]
#  [ 91]
#  [107]
#  [125]
#  [122]
#  [121]
#  [140]
#  [142]
#  [121]
#  [140]
#  [122]
#  [142]
#  [116]
#  [122]
#  [ 75]
#  [114]
#  [ 97]
#  [106]
#  [ 95]
#  [127]
#  [128]
#  [106]
#  [ 94]
#  [133]
#  [106]
#  [ 99]
#  [122]
#  [125]
#  [120]
#  [ 86]
#  [122]
#  [126]
#  [124]
#  [ 88]
#  [ 95]
#  [ 86]
#  [128]
#  [121]
#  [138]
#  [ 94]
#  [121]
#  [143]
#  [121]
#  [140]
#  [124]
#  [138]
#  [107]
#  [120]
#  [125]
#  [128]
#  [107]
#  [142]
#  [ 93]
#  [107]
#  [ 91]
#  [124]
#  [140]
#  [ 87]
#  [121]
#  [103]
#  [138]
#  [125]
#  [ 99]
#  [ 84]
#  [100]
#  [ 99]
#  [124]
#  [ 91]
#  [106]
#  [ 84]
#  [125]
#  [124]
#  [ 90]
#  [122]
#  [133]
#  [112]
#  [123]
#  [135]
#  [105]
#  [116]
#  [143]
#  [134]
#  [118]
#  [100]
#  [121]
#  [124]
#  [146]
#  [ 84]
#  [122]
#  [ 86]
#  [ 87]
#  [100]
#  [125]
#  [112]
#  [146]
#  [140]
#  [ 85]
#  [107]
#  [ 92]
#  [124]
#  [108]
#  [125]
#  [ 95]
#  [122]
#  [111]
#  [ 97]
#  [126]
#  [ 80]
#  [ 90]
#  [125]
#  [ 84]
#  [ 90]
#  [110]
#  [145]
#  [107]
#  [128]
#  [ 86]
#  [125]
#  [140]
#  [ 97]
#  [125]
#  [116]
#  [125]
#  [122]
#  [ 99]
#  [154]
#  [107]
#  [ 87]
#  [135]
#  [140]
#  [120]
#  [ 94]
#  [128]
#  [128]
#  [ 89]
#  [131]
#  [140]
#  [ 97]
#  [108]
#  [ 87]
#  [ 94]
#  [124]
#  [135]
#  [ 87]
#  [ 99]
#  [118]
#  [120]
#  [133]
#  [ 94]
#  [128]
#  [ 84]
#  [140]
#  [ 91]
#  [133]
#  [107]
#  [125]
#  [105]
#  [106]
#  [125]
#  [125]
#  [ 95]
#  [107]
#  [120]
#  [ 99]
#  [125]
#  [138]
#  [105]
#  [ 83]
#  [138]
#  [ 90]
#  [121]
#  [124]
#  [106]
#  [135]
#  [145]
#  [133]
#  [121]
#  [122]
#  [109]
#  [123]
#  [105]
#  [154]
#  [ 85]
#  [136]
#  [ 94]
#  [143]
#  [144]
#  [126]
#  [ 87]
#  [ 87]
#  [ 93]
#  [116]
#  [125]
#  [124]
#  [107]
#  [ 99]
#  [133]
#  [127]
#  [124]
#  [100]
#  [121]
#  [ 97]
#  [ 86]
#  [124]
#  [125]
#  [106]
#  [ 99]
#  [125]
#  [107]
#  [ 95]
#  [125]
#  [ 90]
#  [106]
#  [ 91]
#  [125]
#  [112]
#  [107]
#  [133]
#  [100]
#  [100]
#  [142]
#  [112]
#  [120]
#  [110]
#  [128]
#  [140]
#  [121]
#  [112]
#  [106]
#  [125]
#  [100]
#  [108]
#  [ 94]
#  [125]
#  [ 97]
#  [100]]
# (316, 200, 875)
# (316, 1)

# %%
n_timesteps,n_features,n_outputs= X_train_sbp.shape[1],X_train_sbp.shape[2],y_train_sbp.shape[1]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Flatten, Dense

# Model 1 for Regression
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(n_timesteps, n_features)))

model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='linear'))  # Output layer for regression

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 198, 64)           168064
#
#  flatten (Flatten)           (None, 12672)             0
#
#  dense (Dense)               (None, 64)                811072
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 979201 (3.74 MB)
# Trainable params: 979201 (3.74 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 2024-08-17 14:41:17.510532: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1883] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38698 MB memory:  -> device: 0, name: CUDA GPU, pci bus id: 0000:88:00.0, compute capability: 8.0
# 2024-08-17 14:41:17.512870: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1883] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 38698 MB memory:  -> device: 1, name: CUDA GPU, pci bus id: 0000:8c:00.0, compute capability: 8.0

# %%
# validation_split = 0.1
batch_size = 32

train_epochs = 20
history = model.fit(X_train_sbp, y_train_sbp, epochs=train_epochs, batch_size=batch_size, verbose=True, validation_data = (X_val_sbp, y_val_sbp), shuffle=True)
# Out:
# Epoch 1/20
# 2024-08-17 14:41:19.235080: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2024-08-17 14:41:20.103174: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f3a5e746dc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-08-17 14:41:20.103224: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): CUDA GPU, Compute Capability 8.0
# 2024-08-17 14:41:20.103231: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): CUDA GPU, Compute Capability 8.0
# 2024-08-17 14:41:20.108632: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-08-17 14:41:20.219705: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 10/10 [==============================] - 3s 79ms/step - loss: 3634.8850 - mean_squared_error: 3634.8850 - val_loss: 832.6795 - val_mean_squared_error: 832.6795
# Epoch 2/20
# 10/10 [==============================] - 0s 33ms/step - loss: 828.8491 - mean_squared_error: 828.8491 - val_loss: 689.9026 - val_mean_squared_error: 689.9026
# Epoch 3/20
# 10/10 [==============================] - 0s 22ms/step - loss: 388.6068 - mean_squared_error: 388.6068 - val_loss: 190.5080 - val_mean_squared_error: 190.5080
# Epoch 4/20
# 10/10 [==============================] - 0s 19ms/step - loss: 183.9928 - mean_squared_error: 183.9928 - val_loss: 228.6562 - val_mean_squared_error: 228.6562
# Epoch 5/20
# 10/10 [==============================] - 0s 21ms/step - loss: 107.4552 - mean_squared_error: 107.4552 - val_loss: 156.4786 - val_mean_squared_error: 156.4786
# Epoch 6/20
# 10/10 [==============================] - 0s 20ms/step - loss: 71.5909 - mean_squared_error: 71.5909 - val_loss: 148.4210 - val_mean_squared_error: 148.4210
# Epoch 7/20
# 10/10 [==============================] - 0s 20ms/step - loss: 48.7035 - mean_squared_error: 48.7035 - val_loss: 140.6372 - val_mean_squared_error: 140.6372
# Epoch 8/20
# 10/10 [==============================] - 0s 21ms/step - loss: 34.7545 - mean_squared_error: 34.7545 - val_loss: 141.1970 - val_mean_squared_error: 141.1970
# Epoch 9/20
# 10/10 [==============================] - 0s 18ms/step - loss: 21.3310 - mean_squared_error: 21.3310 - val_loss: 148.9235 - val_mean_squared_error: 148.9235
# Epoch 10/20
# 10/10 [==============================] - 0s 18ms/step - loss: 14.3189 - mean_squared_error: 14.3189 - val_loss: 149.8762 - val_mean_squared_error: 149.8762
# Epoch 11/20
# 10/10 [==============================] - 0s 18ms/step - loss: 10.2455 - mean_squared_error: 10.2455 - val_loss: 143.0711 - val_mean_squared_error: 143.0711
# Epoch 12/20
# 10/10 [==============================] - 0s 19ms/step - loss: 5.4948 - mean_squared_error: 5.4948 - val_loss: 142.4627 - val_mean_squared_error: 142.4627
# Epoch 13/20
# 10/10 [==============================] - 0s 18ms/step - loss: 3.1708 - mean_squared_error: 3.1708 - val_loss: 138.0866 - val_mean_squared_error: 138.0866
# Epoch 14/20
# 10/10 [==============================] - 0s 19ms/step - loss: 1.8355 - mean_squared_error: 1.8355 - val_loss: 138.5408 - val_mean_squared_error: 138.5408
# Epoch 15/20
# 10/10 [==============================] - 0s 19ms/step - loss: 1.4999 - mean_squared_error: 1.4999 - val_loss: 136.9197 - val_mean_squared_error: 136.9197
# Epoch 16/20
# 10/10 [==============================] - 0s 19ms/step - loss: 0.5939 - mean_squared_error: 0.5939 - val_loss: 136.2492 - val_mean_squared_error: 136.2492
# Epoch 17/20
# 10/10 [==============================] - 0s 17ms/step - loss: 0.3206 - mean_squared_error: 0.3206 - val_loss: 135.7745 - val_mean_squared_error: 135.7745
# Epoch 18/20
# 10/10 [==============================] - 0s 17ms/step - loss: 0.1828 - mean_squared_error: 0.1828 - val_loss: 137.1722 - val_mean_squared_error: 137.1722
# Epoch 19/20
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0906 - mean_squared_error: 0.0906 - val_loss: 137.2783 - val_mean_squared_error: 137.2783
# Epoch 20/20
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0431 - mean_squared_error: 0.0431 - val_loss: 136.5127 - val_mean_squared_error: 136.5127

# %%
# 학습 손실 (Training Loss)
plt.plot(history.history['loss'])
# 검증 손실 (Validation Loss)
plt.plot(history.history['val_loss'])

# 그래프 제목 및 축 레이블 설정
plt.title('Model Loss Over Epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')

# 범례 추가
plt.legend(['Train', 'Validation'], loc='upper right')

# 그래프 출력
plt.show()

# %%
# 학습 손실 (Training Loss: Mean Squared Error)
plt.plot(history.history['mean_squared_error'])
# 검증 손실 (Validation Loss: Mean Squared Error)
plt.plot(history.history['val_mean_squared_error'])

# 그래프 제목 및 축 레이블 설정
plt.title('Model Mean Squared Error Over Epochs')
plt.ylabel('Mean Squared Error')
plt.xlabel('Epoch')

# 범례 추가
plt.legend(['Train', 'Validation'], loc='upper right')

# 그래프 출력
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

predy = model.predict(X_sbp)

# 평가 지표 계산
mse = mean_squared_error(y_sbp, predy)
mae = mean_absolute_error(y_sbp, predy)
r2 = r2_score(y_sbp, predy)

print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"R-squared (R²): {r2}")

# 실제값과 예측값 비교 시각화
plt.figure(figsize=(10, 6))
plt.scatter(y_sbp, predy, alpha=0.5)
plt.plot([y_sbp.min(), y_sbp.max()], [y_sbp.min(), y_sbp.max()], 'r--')  # y=x 선
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted')
plt.show()
# Out:
# 16/16 [==============================] - 0s 8ms/step
# Mean Squared Error (MSE): 51.7820980127795
# Mean Absolute Error (MAE): 3.3759147258720015
# R-squared (R²): 0.8382237068904919

# %%
n_timesteps,n_features,n_outputs= X_train_dbp.shape[1],X_train_dbp.shape[2],y_train_dbp.shape[1]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Flatten, Dense

# Model 1 for Regression
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(n_timesteps, n_features)))

model.add(Flatten())

model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='linear'))  # Output layer for regression

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_squared_error'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 198, 64)           168064
#
#  flatten_1 (Flatten)         (None, 12672)             0
#
#  dense_2 (Dense)             (None, 64)                811072
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 979201 (3.74 MB)
# Trainable params: 979201 (3.74 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# validation_split = 0.1
batch_size = 32

train_epochs = 20
history = model.fit(X_train_dbp, y_train_dbp, epochs=train_epochs, batch_size=batch_size, verbose=True, validation_data = (X_val_dbp, y_val_dbp), shuffle=True)
# Out:
# Epoch 1/20
# 10/10 [==============================] - 1s 35ms/step - loss: 818.9159 - mean_squared_error: 818.9159 - val_loss: 360.4053 - val_mean_squared_error: 360.4053
# Epoch 2/20
# 10/10 [==============================] - 0s 13ms/step - loss: 159.5948 - mean_squared_error: 159.5948 - val_loss: 113.8128 - val_mean_squared_error: 113.8128
# Epoch 3/20
# 10/10 [==============================] - 0s 14ms/step - loss: 65.2265 - mean_squared_error: 65.2265 - val_loss: 48.0555 - val_mean_squared_error: 48.0555
# Epoch 4/20
# 10/10 [==============================] - 0s 13ms/step - loss: 27.7597 - mean_squared_error: 27.7597 - val_loss: 52.0704 - val_mean_squared_error: 52.0704
# Epoch 5/20
# 10/10 [==============================] - 0s 15ms/step - loss: 20.1707 - mean_squared_error: 20.1707 - val_loss: 37.6396 - val_mean_squared_error: 37.6396
# Epoch 6/20
# 10/10 [==============================] - 0s 14ms/step - loss: 10.1850 - mean_squared_error: 10.1850 - val_loss: 33.8183 - val_mean_squared_error: 33.8183
# Epoch 7/20
# 10/10 [==============================] - 0s 13ms/step - loss: 4.6979 - mean_squared_error: 4.6979 - val_loss: 32.9432 - val_mean_squared_error: 32.9432
# Epoch 8/20
# 10/10 [==============================] - 0s 16ms/step - loss: 2.6161 - mean_squared_error: 2.6161 - val_loss: 32.0484 - val_mean_squared_error: 32.0484
# Epoch 9/20
# 10/10 [==============================] - 0s 14ms/step - loss: 1.3137 - mean_squared_error: 1.3137 - val_loss: 31.7989 - val_mean_squared_error: 31.7989
# Epoch 10/20
# 10/10 [==============================] - 0s 15ms/step - loss: 0.6341 - mean_squared_error: 0.6341 - val_loss: 31.7984 - val_mean_squared_error: 31.7984
# Epoch 11/20
# 10/10 [==============================] - 0s 14ms/step - loss: 0.3388 - mean_squared_error: 0.3388 - val_loss: 31.0848 - val_mean_squared_error: 31.0848
# Epoch 12/20
# 10/10 [==============================] - 0s 13ms/step - loss: 0.1515 - mean_squared_error: 0.1515 - val_loss: 30.8332 - val_mean_squared_error: 30.8332
# Epoch 13/20
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0888 - mean_squared_error: 0.0888 - val_loss: 31.2959 - val_mean_squared_error: 31.2959
# Epoch 14/20
# 10/10 [==============================] - 0s 16ms/step - loss: 0.0455 - mean_squared_error: 0.0455 - val_loss: 31.6688 - val_mean_squared_error: 31.6688
# Epoch 15/20
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0211 - mean_squared_error: 0.0211 - val_loss: 31.5211 - val_mean_squared_error: 31.5211
# Epoch 16/20
# 10/10 [==============================] - 0s 20ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 31.3655 - val_mean_squared_error: 31.3655
# Epoch 17/20
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 31.3288 - val_mean_squared_error: 31.3288
# Epoch 18/20
# 10/10 [==============================] - 0s 18ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 31.3605 - val_mean_squared_error: 31.3605
# Epoch 19/20
# 10/10 [==============================] - 0s 19ms/step - loss: 6.6762e-04 - mean_squared_error: 6.6762e-04 - val_loss: 31.3059 - val_mean_squared_error: 31.3059
# Epoch 20/20
# 10/10 [==============================] - 0s 19ms/step - loss: 2.5704e-04 - mean_squared_error: 2.5704e-04 - val_loss: 31.3114 - val_mean_squared_error: 31.3114

# %%
# 학습 손실 (Training Loss)
plt.plot(history.history['loss'])
# 검증 손실 (Validation Loss)
plt.plot(history.history['val_loss'])

# 그래프 제목 및 축 레이블 설정
plt.title('Model Loss Over Epochs')
plt.ylabel('Loss')
plt.xlabel('Epoch')

# 범례 추가
plt.legend(['Train', 'Validation'], loc='upper right')

# 그래프 출력
plt.show()

# %%
# 학습 손실 (Training Loss: Mean Squared Error)
plt.plot(history.history['mean_squared_error'])
# 검증 손실 (Validation Loss: Mean Squared Error)
plt.plot(history.history['val_mean_squared_error'])

# 그래프 제목 및 축 레이블 설정
plt.title('Model Mean Squared Error Over Epochs')
plt.ylabel('Mean Squared Error')
plt.xlabel('Epoch')

# 범례 추가
plt.legend(['Train', 'Validation'], loc='upper right')

# 그래프 출력
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

predy = model.predict(X_dbp)

# 평가 지표 계산
mse = mean_squared_error(y_dbp, predy)
mae = mean_absolute_error(y_dbp, predy)
r2 = r2_score(y_dbp, predy)

print(f"Mean Squared Error (MSE): {mse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"R-squared (R²): {r2}")

# 실제값과 예측값 비교 시각화
plt.figure(figsize=(10, 6))
plt.scatter(y_dbp, predy, alpha=0.5)
plt.plot([y_dbp.min(), y_dbp.max()], [y_dbp.min(), y_dbp.max()], 'r--')  # y=x 선
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted')
plt.show()
# Out:
# 16/16 [==============================] - 0s 8ms/step
# Mean Squared Error (MSE): 10.321020485412282
# Mean Absolute Error (MAE): 1.5399630691065933
# R-squared (R²): 0.8723825978418933
