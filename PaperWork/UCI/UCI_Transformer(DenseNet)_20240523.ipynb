# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models

# cnn model vary kernel size
from numpy import mean
from numpy import std
from numpy import dstack
from pandas import read_csv
from matplotlib import pyplot

from tensorflow.keras.utils import to_categorical
import tensorflow.keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Dropout, Flatten, Reshape, LSTM, Conv1D, MaxPooling1D, Bidirectional, ConvLSTM1D
from tensorflow.keras.layers import Input, TimeDistributed, Conv1D, MaxPooling1D, BatchNormalization, GlobalAveragePooling1D, Activation
from tensorflow.python.keras.utils import np_utils
from sklearn.metrics import precision_score, recall_score, f1_score

from typing import Any, Dict, List, Tuple
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# 2024-05-23 11:50:32.509508: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9360] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-23 11:50:32.509588: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-23 11:50:32.509619: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1537] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-23 11:50:32.517780: I tensorflow/core/platform/cpu_feature_guard.cc:183] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns


def load_file(filepath):
    dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
    return dataframe.values



# load a list of files and return as a 3d numpy array
def load_group(filenames, prefix=''):
    loaded = list()
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    # stack group so that features are the 3rd dimension
    loaded = np.dstack(loaded)
    return loaded

# load a dataset group, such as train or test
def load_dataset_group(group, prefix=''):
    filepath = prefix + group + '/Inertial Signals/'
    # load all 9 files as a single array
    filenames = list()
    # total acceleration
    filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
    # body acceleration
    filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
    # body gyroscope
    filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
    # load input data
    X = load_group(filenames, filepath)
    # load class output
    y = load_file(prefix + group + '/y_'+group+'.txt')
    return X, y


# load the dataset, returns train and test X and y elements
# load the dataset, returns train and test X and y elements
def load_dataset(prefix=''):
    # load all train
    trainX, trainy = load_dataset_group('train', prefix + 'UCI HAR Dataset/')
    # load all test
    testX, testy = load_dataset_group('test', prefix + 'UCI HAR Dataset/')

    #zero-offset class values
    trainy = trainy - 1
    testy = testy - 1

    trainy_one_hot = to_categorical(trainy)
    testy_one_hot = to_categorical(testy)
    print(trainX.shape, trainy.shape, trainy_one_hot.shape, testX.shape, testy.shape, testy_one_hot.shape)
    return trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot

# %%
trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot = load_dataset()
# Out:
# (7352, 128, 9) (7352, 1) (7352, 6) (2947, 128, 9) (2947, 1) (2947, 6)

# %%
print("X train shape: ", trainX.shape)
print("Y train shape: ", trainy.shape)
print("Y train One hot shape: ", trainy_one_hot.shape)
print("X test shape: ", testX.shape)
print("Y test shape: ", testy.shape)
print("Y test One hot shape: ", testy_one_hot.shape)
# Out:
# X train shape:  (7352, 128, 9)
# Y train shape:  (7352, 1)
# Y train One hot shape:  (7352, 6)
# X test shape:  (2947, 128, 9)
# Y test shape:  (2947, 1)
# Y test One hot shape:  (2947, 6)

# %%
print("0: Walking:" ,np.where(trainy == 0)[0].size)
print("1: WU:" ,np.where(trainy == 1)[0].size)
print("2: WD:" ,np.where(trainy == 2)[0].size)
print("3: Sitting:" ,np.where(trainy == 3)[0].size)
print("4: Standing:" ,np.where(trainy == 4)[0].size)
print("5: Laying:" ,np.where(trainy == 5)[0].size)
# Out:
# 0: Walking: 1226
# 1: WU: 1073
# 2: WD: 986
# 3: Sitting: 1286
# 4: Standing: 1374
# 5: Laying: 1407

# %%
unique, counts = np.unique(trainy, return_counts=True)
print ("Train data label statistics::")
print (np.asarray((unique, counts)).T)

unique, counts = np.unique(testy, return_counts=True)
print ("Test data label statistics::")
print (np.asarray((unique, counts)).T)
# Out:
# Train data label statistics::
# [[   0 1226]
#  [   1 1073]
#  [   2  986]
#  [   3 1286]
#  [   4 1374]
#  [   5 1407]]
# Test data label statistics::
# [[  0 496]
#  [  1 471]
#  [  2 420]
#  [  3 491]
#  [  4 532]
#  [  5 537]]

# %%
X_train_all = trainX   # at this stage, the data includes both dynamic and static HAR data
y_train_all = trainy

X_test_all = testX
y_test_all = testy

# %%
print("X train shape: ", trainX.shape)
print("Y train shape: ", trainy.shape)
print("Y train One hot shape: ", trainy_one_hot.shape)
print("X test shape: ", testX.shape)
print("Y test shape: ", testy.shape)
print("Y test One hot shape: ", testy_one_hot.shape)
# Out:
# X train shape:  (7352, 128, 9)
# Y train shape:  (7352, 1)
# Y train One hot shape:  (7352, 6)
# X test shape:  (2947, 128, 9)
# Y test shape:  (2947, 1)
# Y test One hot shape:  (2947, 6)

# %%
from sklearn.preprocessing import StandardScaler

def scale_data(trainX, testX):
 # remove overlap
 cut = int(trainX.shape[1] / 2)
 longX = trainX[:, -cut:, :]
 # flatten windows
 longX = longX.reshape((longX.shape[0] * longX.shape[1], longX.shape[2]))
 # flatten train and test
 flatTrainX = trainX.reshape((trainX.shape[0] * trainX.shape[1], trainX.shape[2]))
 flatTestX = testX.reshape((testX.shape[0] * testX.shape[1], testX.shape[2]))

 s = StandardScaler()
 # fit on training data
 s.fit(longX)
 # apply to training and test data
 longX = s.transform(longX)
 flatTrainX = s.transform(flatTrainX)
 flatTestX = s.transform(flatTestX)
 # reshape
 flatTrainX = flatTrainX.reshape((trainX.shape))
 flatTestX = flatTestX.reshape((testX.shape))
 return flatTrainX, flatTestX

# %%
trainX, testX = scale_data(trainX, testX)

# %%
from sklearn.model_selection import train_test_split
X_train,X_val,y_train_one_hot,y_val_one_hot,y_train,y_val=train_test_split(trainX, trainy_one_hot, trainy,test_size=0.3,random_state=100)

# %%
n_timesteps, n_features, n_outputs = trainX.shape[1], trainX.shape[2], trainy_one_hot.shape[1]

# %%
n_classes = 6

# %%
def dense_block(x, units, dropout=0):
    for _ in range(3):  # DenseNet 블록 
        x1 = layers.Dense(units, activation="relu")(x)
        x1 = layers.Dropout(dropout)(x1)
        x1 = layers.LayerNormalization(epsilon=1e-6)(x1)
        x = layers.Concatenate()([x, x1])
    return x

def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Attention and Normalization
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(inputs, inputs)
    x = layers.Dropout(dropout)(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    res = x + inputs

    # Feed Forward Part using DenseNet
    x = dense_block(res, ff_dim, dropout)
    x = layers.Dense(inputs.shape[-1])(x)
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    return x + res

# %%
"""
The main part of our model is now complete. We can stack multiple of those
`transformer_encoder` blocks and we can also proceed to add the final
Multi-Layer Perceptron classification head. Apart from a stack of `Dense`
layers, we need to reduce the output tensor of the `TransformerEncoder` part of
our model down to a vector of features for each data point in the current
batch. A common way to achieve this is to use a pooling layer. For
this example, a `GlobalAveragePooling1D` layer is sufficient.
"""


def build_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    # input_shape 튜플 풀기
    n_steps, n_features = input_shape
    
    inputs = keras.Input(shape=(n_steps, n_features))
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(n_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs)

# %%
"""
## Train and evaluate
"""

input_shape = X_train.shape[1:]

model = build_model(
    input_shape,
    head_size=256,
    num_heads=4,
    ff_dim=4,
    num_transformer_blocks=4,
    mlp_units=[128],
    mlp_dropout=0.4,
    dropout=0.25,
)

model.compile(
    loss="categorical_crossentropy",
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    metrics=["accuracy"],
)
model.summary()

callbacks = [keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)]
# Out:
# 2024-05-23 11:50:40.349182: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1883] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38698 MB memory:  -> device: 0, name: CUDA GPU, pci bus id: 0000:88:00.0, compute capability: 8.0
# 2024-05-23 11:50:40.351443: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1883] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 38698 MB memory:  -> device: 1, name: CUDA GPU, pci bus id: 0000:c8:00.0, compute capability: 8.0
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 9)]             0         []
#
#  multi_head_attention (Mult  (None, 128, 9)               39945     ['input_1[0][0]',
#  iHeadAttention)                                                     'input_1[0][0]']
#
#  dropout (Dropout)           (None, 128, 9)               0         ['multi_head_attention[0][0]']
#
#  layer_normalization (Layer  (None, 128, 9)               18        ['dropout[0][0]']
#  Normalization)
#
#  tf.__operators__.add (TFOp  (None, 128, 9)               0         ['layer_normalization[0][0]',
#  Lambda)                                                             'input_1[0][0]']
#
#  dense (Dense)               (None, 128, 4)               40        ['tf.__operators__.add[0][0]']
#
#  dropout_1 (Dropout)         (None, 128, 4)               0         ['dense[0][0]']
#
#  layer_normalization_1 (Lay  (None, 128, 4)               8         ['dropout_1[0][0]']
#  erNormalization)
#
#  concatenate (Concatenate)   (None, 128, 13)              0         ['tf.__operators__.add[0][0]',
#                                                                      'layer_normalization_1[0][0]'
#                                                                     ]
#
#  dense_1 (Dense)             (None, 128, 4)               56        ['concatenate[0][0]']
#
#  dropout_2 (Dropout)         (None, 128, 4)               0         ['dense_1[0][0]']
#
#  layer_normalization_2 (Lay  (None, 128, 4)               8         ['dropout_2[0][0]']
#  erNormalization)
#
#  concatenate_1 (Concatenate  (None, 128, 17)              0         ['concatenate[0][0]',
#  )                                                                   'layer_normalization_2[0][0]'
#                                                                     ]
#
#  dense_2 (Dense)             (None, 128, 4)               72        ['concatenate_1[0][0]']
#
#  dropout_3 (Dropout)         (None, 128, 4)               0         ['dense_2[0][0]']
#
#  layer_normalization_3 (Lay  (None, 128, 4)               8         ['dropout_3[0][0]']
#  erNormalization)
#
#  concatenate_2 (Concatenate  (None, 128, 21)              0         ['concatenate_1[0][0]',
#  )                                                                   'layer_normalization_3[0][0]'
#                                                                     ]
#
#  dense_3 (Dense)             (None, 128, 9)               198       ['concatenate_2[0][0]']
#
#  layer_normalization_4 (Lay  (None, 128, 9)               18        ['dense_3[0][0]']
#  erNormalization)
#
#  tf.__operators__.add_1 (TF  (None, 128, 9)               0         ['layer_normalization_4[0][0]'
#  OpLambda)                                                          , 'tf.__operators__.add[0][0]'
#                                                                     ]
#
#  multi_head_attention_1 (Mu  (None, 128, 9)               39945     ['tf.__operators__.add_1[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'tf.__operators__.add_1[0][0]
#                                                                     ']
#
#  dropout_4 (Dropout)         (None, 128, 9)               0         ['multi_head_attention_1[0][0]
#                                                                     ']
#
#  layer_normalization_5 (Lay  (None, 128, 9)               18        ['dropout_4[0][0]']
#  erNormalization)
#
#  tf.__operators__.add_2 (TF  (None, 128, 9)               0         ['layer_normalization_5[0][0]'
#  OpLambda)                                                          , 'tf.__operators__.add_1[0][0
#                                                                     ]']
#
#  dense_4 (Dense)             (None, 128, 4)               40        ['tf.__operators__.add_2[0][0]
#                                                                     ']
#
#  dropout_5 (Dropout)         (None, 128, 4)               0         ['dense_4[0][0]']
#
#  layer_normalization_6 (Lay  (None, 128, 4)               8         ['dropout_5[0][0]']
#  erNormalization)
#
#  concatenate_3 (Concatenate  (None, 128, 13)              0         ['tf.__operators__.add_2[0][0]
#  )                                                                  ',
#                                                                      'layer_normalization_6[0][0]'
#                                                                     ]
#
#  dense_5 (Dense)             (None, 128, 4)               56        ['concatenate_3[0][0]']
#
#  dropout_6 (Dropout)         (None, 128, 4)               0         ['dense_5[0][0]']
#
#  layer_normalization_7 (Lay  (None, 128, 4)               8         ['dropout_6[0][0]']
#  erNormalization)
#
#  concatenate_4 (Concatenate  (None, 128, 17)              0         ['concatenate_3[0][0]',
#  )                                                                   'layer_normalization_7[0][0]'
#                                                                     ]
#
#  dense_6 (Dense)             (None, 128, 4)               72        ['concatenate_4[0][0]']
#
#  dropout_7 (Dropout)         (None, 128, 4)               0         ['dense_6[0][0]']
#
#  layer_normalization_8 (Lay  (None, 128, 4)               8         ['dropout_7[0][0]']
#  erNormalization)
#
#  concatenate_5 (Concatenate  (None, 128, 21)              0         ['concatenate_4[0][0]',
#  )                                                                   'layer_normalization_8[0][0]'
#                                                                     ]
#
#  dense_7 (Dense)             (None, 128, 9)               198       ['concatenate_5[0][0]']
#
#  layer_normalization_9 (Lay  (None, 128, 9)               18        ['dense_7[0][0]']
#  erNormalization)
#
#  tf.__operators__.add_3 (TF  (None, 128, 9)               0         ['layer_normalization_9[0][0]'
#  OpLambda)                                                          , 'tf.__operators__.add_2[0][0
#                                                                     ]']
#
#  multi_head_attention_2 (Mu  (None, 128, 9)               39945     ['tf.__operators__.add_3[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'tf.__operators__.add_3[0][0]
#                                                                     ']
#
#  dropout_8 (Dropout)         (None, 128, 9)               0         ['multi_head_attention_2[0][0]
#                                                                     ']
#
#  layer_normalization_10 (La  (None, 128, 9)               18        ['dropout_8[0][0]']
#  yerNormalization)
#
#  tf.__operators__.add_4 (TF  (None, 128, 9)               0         ['layer_normalization_10[0][0]
#  OpLambda)                                                          ',
#                                                                      'tf.__operators__.add_3[0][0]
#                                                                     ']
#
#  dense_8 (Dense)             (None, 128, 4)               40        ['tf.__operators__.add_4[0][0]
#                                                                     ']
#
#  dropout_9 (Dropout)         (None, 128, 4)               0         ['dense_8[0][0]']
#
#  layer_normalization_11 (La  (None, 128, 4)               8         ['dropout_9[0][0]']
#  yerNormalization)
#
#  concatenate_6 (Concatenate  (None, 128, 13)              0         ['tf.__operators__.add_4[0][0]
#  )                                                                  ',
#                                                                      'layer_normalization_11[0][0]
#                                                                     ']
#
#  dense_9 (Dense)             (None, 128, 4)               56        ['concatenate_6[0][0]']
#
#  dropout_10 (Dropout)        (None, 128, 4)               0         ['dense_9[0][0]']
#
#  layer_normalization_12 (La  (None, 128, 4)               8         ['dropout_10[0][0]']
#  yerNormalization)
#
#  concatenate_7 (Concatenate  (None, 128, 17)              0         ['concatenate_6[0][0]',
#  )                                                                   'layer_normalization_12[0][0]
#                                                                     ']
#
#  dense_10 (Dense)            (None, 128, 4)               72        ['concatenate_7[0][0]']
#
#  dropout_11 (Dropout)        (None, 128, 4)               0         ['dense_10[0][0]']
#
#  layer_normalization_13 (La  (None, 128, 4)               8         ['dropout_11[0][0]']
#  yerNormalization)
#
#  concatenate_8 (Concatenate  (None, 128, 21)              0         ['concatenate_7[0][0]',
#  )                                                                   'layer_normalization_13[0][0]
#                                                                     ']
#
#  dense_11 (Dense)            (None, 128, 9)               198       ['concatenate_8[0][0]']
#
#  layer_normalization_14 (La  (None, 128, 9)               18        ['dense_11[0][0]']
#  yerNormalization)
#
#  tf.__operators__.add_5 (TF  (None, 128, 9)               0         ['layer_normalization_14[0][0]
#  OpLambda)                                                          ',
#                                                                      'tf.__operators__.add_4[0][0]
#                                                                     ']
#
#  multi_head_attention_3 (Mu  (None, 128, 9)               39945     ['tf.__operators__.add_5[0][0]
#  ltiHeadAttention)                                                  ',
#                                                                      'tf.__operators__.add_5[0][0]
#                                                                     ']
#
#  dropout_12 (Dropout)        (None, 128, 9)               0         ['multi_head_attention_3[0][0]
#                                                                     ']
#
#  layer_normalization_15 (La  (None, 128, 9)               18        ['dropout_12[0][0]']
#  yerNormalization)
#
#  tf.__operators__.add_6 (TF  (None, 128, 9)               0         ['layer_normalization_15[0][0]
#  OpLambda)                                                          ',
#                                                                      'tf.__operators__.add_5[0][0]
#                                                                     ']
#
#  dense_12 (Dense)            (None, 128, 4)               40        ['tf.__operators__.add_6[0][0]
#                                                                     ']
#
#  dropout_13 (Dropout)        (None, 128, 4)               0         ['dense_12[0][0]']
#
#  layer_normalization_16 (La  (None, 128, 4)               8         ['dropout_13[0][0]']
#  yerNormalization)
#
#  concatenate_9 (Concatenate  (None, 128, 13)              0         ['tf.__operators__.add_6[0][0]
#  )                                                                  ',
#                                                                      'layer_normalization_16[0][0]
#                                                                     ']
#
#  dense_13 (Dense)            (None, 128, 4)               56        ['concatenate_9[0][0]']
#
#  dropout_14 (Dropout)        (None, 128, 4)               0         ['dense_13[0][0]']
#
#  layer_normalization_17 (La  (None, 128, 4)               8         ['dropout_14[0][0]']
#  yerNormalization)
#
#  concatenate_10 (Concatenat  (None, 128, 17)              0         ['concatenate_9[0][0]',
#  e)                                                                  'layer_normalization_17[0][0]
#                                                                     ']
#
#  dense_14 (Dense)            (None, 128, 4)               72        ['concatenate_10[0][0]']
#
#  dropout_15 (Dropout)        (None, 128, 4)               0         ['dense_14[0][0]']
#
#  layer_normalization_18 (La  (None, 128, 4)               8         ['dropout_15[0][0]']
#  yerNormalization)
#
#  concatenate_11 (Concatenat  (None, 128, 21)              0         ['concatenate_10[0][0]',
#  e)                                                                  'layer_normalization_18[0][0]
#                                                                     ']
#
#  dense_15 (Dense)            (None, 128, 9)               198       ['concatenate_11[0][0]']
#
#  layer_normalization_19 (La  (None, 128, 9)               18        ['dense_15[0][0]']
#  yerNormalization)
#
#  tf.__operators__.add_7 (TF  (None, 128, 9)               0         ['layer_normalization_19[0][0]
#  OpLambda)                                                          ',
#                                                                      'tf.__operators__.add_6[0][0]
#                                                                     ']
#
#  global_average_pooling1d (  (None, 128)                  0         ['tf.__operators__.add_7[0][0]
#  GlobalAveragePooling1D)                                            ']
#
#  dense_16 (Dense)            (None, 128)                  16512     ['global_average_pooling1d[0][
#                                                                     0]']
#
#  dropout_16 (Dropout)        (None, 128)                  0         ['dense_16[0][0]']
#
#  dense_17 (Dense)            (None, 6)                    774       ['dropout_16[0][0]']
# ==================================================================================================
# Total params: 178770 (698.32 KB)
# Trainable params: 178770 (698.32 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True)

# %%
history = model.fit(
    X_train,
    y_train_one_hot,
    validation_data=(X_val, y_val_one_hot),
    epochs=200,
    batch_size=64,
    callbacks=callbacks,
)

model.evaluate(testX, testy_one_hot, verbose=1)
# Out:
# Epoch 1/200
# 2024-05-23 11:50:54.796541: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f51a5407c40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-05-23 11:50:54.796602: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): CUDA GPU, Compute Capability 8.0
# 2024-05-23 11:50:54.796616: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): CUDA GPU, Compute Capability 8.0
# 2024-05-23 11:50:54.801509: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-05-23 11:50:55.905458: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8907
# 2024-05-23 11:50:55.975907: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 81/81 [==============================] - 22s 47ms/step - loss: 1.7103 - accuracy: 0.2771 - val_loss: 1.5774 - val_accuracy: 0.3323
# Epoch 2/200
# 81/81 [==============================] - 3s 37ms/step - loss: 1.5056 - accuracy: 0.3659 - val_loss: 1.3930 - val_accuracy: 0.3953
# Epoch 3/200
# 81/81 [==============================] - 3s 37ms/step - loss: 1.3512 - accuracy: 0.4683 - val_loss: 1.2883 - val_accuracy: 0.5435
# Epoch 4/200
# 81/81 [==============================] - 3s 37ms/step - loss: 1.2749 - accuracy: 0.5291 - val_loss: 1.2267 - val_accuracy: 0.5743
# Epoch 5/200
# 81/81 [==============================] - 3s 39ms/step - loss: 1.2254 - accuracy: 0.5513 - val_loss: 1.1810 - val_accuracy: 0.5920
# Epoch 6/200
# 81/81 [==============================] - 3s 37ms/step - loss: 1.1728 - accuracy: 0.5770 - val_loss: 1.1451 - val_accuracy: 0.5997
# Epoch 7/200
# 81/81 [==============================] - 3s 37ms/step - loss: 1.1432 - accuracy: 0.5942 - val_loss: 1.1076 - val_accuracy: 0.6201
# Epoch 8/200
# 81/81 [==============================] - 3s 36ms/step - loss: 1.1033 - accuracy: 0.6082 - val_loss: 1.0553 - val_accuracy: 0.6138
# Epoch 9/200
# 81/81 [==============================] - 3s 37ms/step - loss: 1.0467 - accuracy: 0.6174 - val_loss: 0.9956 - val_accuracy: 0.6374
# Epoch 10/200
# 81/81 [==============================] - 3s 37ms/step - loss: 1.0002 - accuracy: 0.6374 - val_loss: 0.9331 - val_accuracy: 0.6727
# Epoch 11/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.9305 - accuracy: 0.6617 - val_loss: 0.8975 - val_accuracy: 0.6754
# Epoch 12/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.8693 - accuracy: 0.6943 - val_loss: 0.8226 - val_accuracy: 0.7026
# Epoch 13/200
# 81/81 [==============================] - 4s 44ms/step - loss: 0.8263 - accuracy: 0.7044 - val_loss: 0.7740 - val_accuracy: 0.7298
# Epoch 14/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.7877 - accuracy: 0.7206 - val_loss: 0.7711 - val_accuracy: 0.7516
# Epoch 15/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.7512 - accuracy: 0.7363 - val_loss: 0.6984 - val_accuracy: 0.7584
# Epoch 16/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.7091 - accuracy: 0.7662 - val_loss: 0.6841 - val_accuracy: 0.7824
# Epoch 17/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.6744 - accuracy: 0.7719 - val_loss: 0.6687 - val_accuracy: 0.7888
# Epoch 18/200
# 81/81 [==============================] - 3s 40ms/step - loss: 0.6529 - accuracy: 0.7818 - val_loss: 0.6366 - val_accuracy: 0.8055
# Epoch 19/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.6242 - accuracy: 0.7940 - val_loss: 0.5608 - val_accuracy: 0.8318
# Epoch 20/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.5782 - accuracy: 0.8156 - val_loss: 0.5836 - val_accuracy: 0.8096
# Epoch 21/200
# 81/81 [==============================] - 3s 36ms/step - loss: 0.5633 - accuracy: 0.8210 - val_loss: 0.4848 - val_accuracy: 0.8504
# Epoch 22/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.5275 - accuracy: 0.8302 - val_loss: 0.4936 - val_accuracy: 0.8323
# Epoch 23/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.5300 - accuracy: 0.8352 - val_loss: 0.4721 - val_accuracy: 0.8432
# Epoch 24/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.4925 - accuracy: 0.8484 - val_loss: 0.4690 - val_accuracy: 0.8463
# Epoch 25/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.4819 - accuracy: 0.8490 - val_loss: 0.4381 - val_accuracy: 0.8531
# Epoch 26/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.4645 - accuracy: 0.8498 - val_loss: 0.4552 - val_accuracy: 0.8318
# Epoch 27/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.4391 - accuracy: 0.8589 - val_loss: 0.4120 - val_accuracy: 0.8558
# Epoch 28/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.4361 - accuracy: 0.8576 - val_loss: 0.3882 - val_accuracy: 0.8636
# Epoch 29/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.4103 - accuracy: 0.8690 - val_loss: 0.3663 - val_accuracy: 0.8667
# Epoch 30/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.4027 - accuracy: 0.8688 - val_loss: 0.3476 - val_accuracy: 0.8722
# Epoch 31/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.3860 - accuracy: 0.8752 - val_loss: 0.3276 - val_accuracy: 0.8858
# Epoch 32/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.3797 - accuracy: 0.8820 - val_loss: 0.3338 - val_accuracy: 0.8826
# Epoch 33/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.3683 - accuracy: 0.8799 - val_loss: 0.3714 - val_accuracy: 0.8663
# Epoch 34/200
# 81/81 [==============================] - 3s 38ms/step - loss: 0.3562 - accuracy: 0.8881 - val_loss: 0.3580 - val_accuracy: 0.8708
# Epoch 35/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.3445 - accuracy: 0.8898 - val_loss: 0.3157 - val_accuracy: 0.8939
# Epoch 36/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.3262 - accuracy: 0.8984 - val_loss: 0.2919 - val_accuracy: 0.9093
# Epoch 37/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.3210 - accuracy: 0.8988 - val_loss: 0.3081 - val_accuracy: 0.8966
# Epoch 38/200
# 81/81 [==============================] - 4s 46ms/step - loss: 0.3148 - accuracy: 0.9017 - val_loss: 0.3052 - val_accuracy: 0.8921
# Epoch 39/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.3084 - accuracy: 0.9017 - val_loss: 0.3180 - val_accuracy: 0.8799
# Epoch 40/200
# 81/81 [==============================] - 3s 36ms/step - loss: 0.3036 - accuracy: 0.8956 - val_loss: 0.2769 - val_accuracy: 0.9030
# Epoch 41/200
# 81/81 [==============================] - 3s 39ms/step - loss: 0.2935 - accuracy: 0.9017 - val_loss: 0.3152 - val_accuracy: 0.8930
# Epoch 42/200
# 81/81 [==============================] - 3s 36ms/step - loss: 0.2856 - accuracy: 0.9034 - val_loss: 0.2760 - val_accuracy: 0.9066
# Epoch 43/200
# 81/81 [==============================] - 3s 36ms/step - loss: 0.2752 - accuracy: 0.9085 - val_loss: 0.3058 - val_accuracy: 0.8971
# Epoch 44/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.2712 - accuracy: 0.9094 - val_loss: 0.2690 - val_accuracy: 0.9152
# Epoch 45/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.2624 - accuracy: 0.9120 - val_loss: 0.3110 - val_accuracy: 0.8994
# Epoch 46/200
# 81/81 [==============================] - 4s 44ms/step - loss: 0.2692 - accuracy: 0.9124 - val_loss: 0.2904 - val_accuracy: 0.8994
# Epoch 47/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.2616 - accuracy: 0.9116 - val_loss: 0.2684 - val_accuracy: 0.9048
# Epoch 48/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.2493 - accuracy: 0.9180 - val_loss: 0.2891 - val_accuracy: 0.9062
# Epoch 49/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.2443 - accuracy: 0.9184 - val_loss: 0.3036 - val_accuracy: 0.9025
# Epoch 50/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.2443 - accuracy: 0.9151 - val_loss: 0.2479 - val_accuracy: 0.9170
# Epoch 51/200
# 81/81 [==============================] - 3s 42ms/step - loss: 0.2387 - accuracy: 0.9151 - val_loss: 0.2635 - val_accuracy: 0.9170
# Epoch 52/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.2337 - accuracy: 0.9211 - val_loss: 0.2922 - val_accuracy: 0.9039
# Epoch 53/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.2348 - accuracy: 0.9186 - val_loss: 0.2361 - val_accuracy: 0.9180
# Epoch 54/200
# 81/81 [==============================] - 3s 38ms/step - loss: 0.2278 - accuracy: 0.9207 - val_loss: 0.2420 - val_accuracy: 0.9121
# Epoch 55/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.2261 - accuracy: 0.9199 - val_loss: 0.2684 - val_accuracy: 0.9125
# Epoch 56/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.2135 - accuracy: 0.9267 - val_loss: 0.2585 - val_accuracy: 0.9184
# Epoch 57/200
# 81/81 [==============================] - 3s 37ms/step - loss: 0.2182 - accuracy: 0.9258 - val_loss: 0.2436 - val_accuracy: 0.9170
# Epoch 58/200
# 81/81 [==============================] - 3s 40ms/step - loss: 0.2087 - accuracy: 0.9318 - val_loss: 0.2679 - val_accuracy: 0.9134
# 93/93 [==============================] - 1s 10ms/step - loss: 0.4300 - accuracy: 0.8582
# [0.4300466775894165, 0.8581608533859253]

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracys')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %%
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

predy=model.predict(testX)
predy=np.argmax(predy, axis=-1)
LABELS = ['WALKING','WALKING_UPSTAIRS','WALKING_DOWNSTAIRS', 'SITTING','STANDIND','LAYING']
cm=confusion_matrix(testy,predy)
plot_confusion_matrix(conf_mat=cm, class_names=LABELS, show_normed=True, figsize=(7,7))
# Out:
# 93/93 [==============================] - 2s 10ms/step
# (<Figure size 700x700 with 1 Axes>,
#  <Axes: xlabel='predicted label', ylabel='true label'>)

# %%
print(cm)
print(accuracy_score(testy,predy))
print(f1_score(testy,predy, average='weighted'))
print(classification_report(testy,predy))
# Out:
# [[398  34  64   0   0   0]
#  [ 10 390  37   0  34   0]
#  [ 39   7 373   0   0   1]
#  [  0   1   0 328 157   5]
#  [  0   1   0  26 505   0]
#  [  0   0   1   1   0 535]]
# 0.8581608415337632
# 0.8572965054239307
#               precision    recall  f1-score   support
#
#            0       0.89      0.80      0.84       496
#            1       0.90      0.83      0.86       471
#            2       0.79      0.89      0.83       420
#            3       0.92      0.67      0.78       491
#            4       0.73      0.95      0.82       532
#            5       0.99      1.00      0.99       537
#
#     accuracy                           0.86      2947
#    macro avg       0.87      0.86      0.86      2947
# weighted avg       0.87      0.86      0.86      2947
