# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from pandas.plotting import register_matplotlib_converters
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
from pandas import read_csv, unique

import numpy as np
import pandas as pd

from scipy.interpolate import interp1d
from scipy.stats import mode

from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

from tensorflow import stack
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dropout, Dense
from keras.layers import Dense, GlobalAveragePooling1D, BatchNormalization, MaxPool1D, Reshape, Activation
from tensorflow.keras.layers import Conv1D, Flatten, Reshape, MaxPooling1D
from keras.callbacks import ModelCheckpoint, EarlyStopping
import matplotlib.pyplot as plt

# %%
names = ["NaN", "user_id", "activity", "timestamp", "x_axis", "y_axis", "z_axis"]
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/data/WISDM.csv", header=None, names=names, skiprows=1)

def convert_to_float(x):
    try:
        return np.float(x)
    except:
        return np.nan

df = data.drop('NaN', axis=1)
df["z_axis"].replace(regex = True, inplace = True, to_replace = r';', value = r'')
    # ... and then this column must be transformed to float explicitly
df.dropna(axis=0, how='any', inplace=True)
df.head()
print(df.shape)
# Out:
# (1098203, 6)

# %%
df.head()
# Out:
#    user_id activity       timestamp    x_axis     y_axis    z_axis
# 0       33  Jogging  49105962326000 -0.694638  12.680544  0.503953
# 1       33  Jogging  49106062271000  5.012288  11.264028  0.953424
# 2       33  Jogging  49106112167000  4.903325  10.882658 -0.081722
# 3       33  Jogging  49106222305000 -0.612916  18.496431  3.023717
# 4       33  Jogging  49106332290000 -1.184970  12.108489  7.205164

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1098203 entries, 0 to 1098202
# Data columns (total 6 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   user_id    1098203 non-null  int64
#  1   activity   1098203 non-null  object
#  2   timestamp  1098203 non-null  int64
#  3   x_axis     1098203 non-null  float64
#  4   y_axis     1098203 non-null  float64
#  5   z_axis     1098203 non-null  float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 50.3+ MB

# %%
df = df[~df['activity'].str.contains('Jogging|Sitting|Upstairs|Downstairs')]

# %%
mapping = {'Walking': 0, 'Standing': 1}

# 레이블 인코딩
df['ActivityEncoded'] = df['activity'].map(mapping)
df
# Out:
# <ipython-input-7-cda07a43a212>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ActivityEncoded'] = df['activity'].map(mapping)
#          user_id  activity        timestamp    x_axis     y_axis    z_axis  \
# 597           33   Walking   49394992294000  0.844462   8.008764  2.792171
# 598           33   Walking   49395102310000  1.116869   8.621680  3.786457
# 599           33   Walking   49395202316000 -0.503953  16.657684  1.307553
# 600           33   Walking   49395302292000  4.794363  10.760075 -1.184970
# 601           33   Walking   49395412338000 -0.040861   9.234595 -0.694638
# ...          ...       ...              ...       ...        ...       ...
# 1095664       19  Standing  131477821443000 -4.990000   8.390000 -0.380000
# 1095665       19  Standing  131477861513000 -5.130000   8.240000 -0.420000
# 1095666       19  Standing  131477941499000 -4.560000   8.500000 -0.890000
# 1095667       19  Standing  131477981508000 -4.480000   8.540000 -1.080000
# 1095668       19  Standing  131478021486000 -4.940000   8.280000 -0.840000
#
#          ActivityEncoded
# 597                    0
# 598                    0
# 599                    0
# 600                    0
# 601                    0
# ...                  ...
# 1095664                1
# 1095665                1
# 1095666                1
# 1095667                1
# 1095668                1
#
# [472792 rows x 7 columns]

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x = "activity", data = df, order = df.activity.value_counts().index)
# Out:
# <Axes: xlabel='activity', ylabel='count'>

# %%
df.activity.value_counts()
# Out:
# Walking     424397
# Standing     48395
# Name: activity, dtype: int64

# %%
standing_data = df[df['activity'] == 'Standing']  # 'Standing' 행만 추출
num_repeats = 8  # 'Standing' 행을 몇 번 반복할지 결정
standing_data_repeated = pd.concat([standing_data] * num_repeats, ignore_index=True)  # 'Standing' 행을 복사하여 여러 번 반복

# 데이터프레임에 추가
df = pd.concat([df, standing_data_repeated], ignore_index=True)

# 결과 확인
print(df['activity'].value_counts())
# Out:
# Standing    435555
# Walking     424397
# Name: activity, dtype: int64

# %%
df
# Out:
#         user_id  activity        timestamp    x_axis     y_axis    z_axis  \
# 0            33   Walking   49394992294000  0.844462   8.008764  2.792171
# 1            33   Walking   49395102310000  1.116869   8.621680  3.786457
# 2            33   Walking   49395202316000 -0.503953  16.657684  1.307553
# 3            33   Walking   49395302292000  4.794363  10.760075 -1.184970
# 4            33   Walking   49395412338000 -0.040861   9.234595 -0.694638
# ...         ...       ...              ...       ...        ...       ...
# 859947       19  Standing  131477821443000 -4.990000   8.390000 -0.380000
# 859948       19  Standing  131477861513000 -5.130000   8.240000 -0.420000
# 859949       19  Standing  131477941499000 -4.560000   8.500000 -0.890000
# 859950       19  Standing  131477981508000 -4.480000   8.540000 -1.080000
# 859951       19  Standing  131478021486000 -4.940000   8.280000 -0.840000
#
#         ActivityEncoded
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 859947                1
# 859948                1
# 859949                1
# 859950                1
# 859951                1
#
# [859952 rows x 7 columns]

# %%
plt.figure(figsize=(18, 6))
sns.countplot(x = "user_id", data = df, palette = [sns.color_palette()[0]],
              order = df.user_id.value_counts().index)
plt.title("Records per user");
# Out:
# <ipython-input-12-246fd3e84525>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = "user_id", data = df, palette = [sns.color_palette()[0]],
# <ipython-input-12-246fd3e84525>:2: UserWarning:
# The palette list has fewer values (1) than needed (36) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(x = "user_id", data = df, palette = [sns.color_palette()[0]],

# %%
def plot_activity(activity, df):
    data = df[df["activity"] == activity][["x_axis", "y_axis", "z_axis"]][:200]
    axis = data.plot(subplots = True, figsize = (16, 12), title = activity)
    for ax in axis:
        ax.legend(loc = "lower left", bbox_to_anchor = (1.0, 0.5))

plot_activity("Standing", df)

# %%
from scipy import stats

def create_dataset(X, y, time_steps=1, step=1):
    Xs, ys = [], []
    for i in range(0, len(X) - time_steps, step):
        v = X.iloc[i:(i + time_steps)].values
        labels = y.iloc[i: i + time_steps]
        Xs.append(v)
        ys.append(stats.mode(labels)[0])
    return np.array(Xs), np.array(ys).reshape(-1, 1)

TIME_STEPS = 200
STEP = 40

X_data, y_data = create_dataset(df[["x_axis", "y_axis", "z_axis"]], df.ActivityEncoded, TIME_STEPS,
                                  STEP)

X_train, X_test,y_train, y_test = train_test_split(X_data, y_data, test_size = 0.2, stratify=  y_data )
X_train, X_val, y_train, y_val  = train_test_split(X_train, y_train, test_size = 0.2, stratify=  y_train )
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (13756, 200, 3) (13756, 1)
# (4299, 200, 3) (4299, 1)

# %%
from sklearn.preprocessing import OneHotEncoder

enc = OneHotEncoder(handle_unknown = "ignore", sparse_output = False)
enc = enc.fit(y_train)

y_train_hot = enc.transform(y_train)
y_test_hot = enc.transform(y_test)
y_val_hot = enc.transform(y_val)

print(X_train.shape, y_train_hot.shape, X_test.shape, y_test_hot.shape)
# Out:
# (13756, 200, 3) (13756, 2) (4299, 200, 3) (4299, 2)

# %%
#Epoch 10

BATCH_SIZE = 32

verbose,epochs,batch_size=1,10, BATCH_SIZE

n_timesteps,n_features,n_outputs= X_train.shape[1],X_train.shape[2],y_train_hot.shape[1]
n_timesteps,n_features,n_outputs
# Out:
# (200, 3, 2)

# %% [markdown]
# <h1> CNN 1 </h1>

# %%
# Model 1
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(n_timesteps,n_features)))
model.add(Dropout(0.5))
model.add(MaxPooling1D(pool_size=2))

model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dense(n_outputs, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 198, 64)           640
#
#  dropout_1 (Dropout)         (None, 198, 64)           0
#
#  max_pooling1d_1 (MaxPoolin  (None, 99, 64)            0
#  g1D)
#
#  flatten_1 (Flatten)         (None, 6336)              0
#
#  dense_2 (Dense)             (None, 128)               811136
#
#  dense_3 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 812034 (3.10 MB)
# Trainable params: 812034 (3.10 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# validation_split = 0.1
batch_size = 128

train_epochs = 10
history = model.fit(X_train, y_train_hot, epochs=train_epochs, batch_size=batch_size, verbose=True,  validation_data = (X_val, y_val_hot), shuffle=True)
# Out:
# Epoch 1/10
# 108/108 [==============================] - 2s 8ms/step - loss: 0.3297 - accuracy: 0.9594 - val_loss: 0.0124 - val_accuracy: 0.9974
# Epoch 2/10
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0059 - accuracy: 0.9985 - val_loss: 0.0092 - val_accuracy: 0.9977
# Epoch 3/10
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.0138 - val_accuracy: 0.9971
# Epoch 4/10
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.0088 - val_accuracy: 0.9974
# Epoch 5/10
# 108/108 [==============================] - 1s 5ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.0152 - val_accuracy: 0.9968
# Epoch 6/10
# 108/108 [==============================] - 1s 6ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0104 - val_accuracy: 0.9974
# Epoch 7/10
# 108/108 [==============================] - 1s 5ms/step - loss: 3.9344e-04 - accuracy: 0.9999 - val_loss: 0.0087 - val_accuracy: 0.9977
# Epoch 8/10
# 108/108 [==============================] - 1s 5ms/step - loss: 6.7369e-04 - accuracy: 0.9999 - val_loss: 0.0080 - val_accuracy: 0.9977
# Epoch 9/10
# 108/108 [==============================] - 1s 5ms/step - loss: 2.6359e-04 - accuracy: 1.0000 - val_loss: 0.0114 - val_accuracy: 0.9974
# Epoch 10/10
# 108/108 [==============================] - 1s 5ms/step - loss: 1.5812e-04 - accuracy: 1.0000 - val_loss: 0.0110 - val_accuracy: 0.9974

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Training and validation accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

y_pred=model.predict(X_test)
y_pred = np.argmax(y_pred, axis=-1)
y_true = np.argmax(y_test_hot, axis=-1)

LABELS = ['Walking''Standing']
cm=confusion_matrix(y_true,y_pred)

#print(cm)
print('f1_score = ', f1_score(y_true, y_pred, average='weighted'))
print(accuracy_score(y_true,y_pred))
print(classification_report(y_true,y_pred))
sns.heatmap(cm, cmap="YlGnBu", xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt = '.2f')
# Out:
# 135/135 [==============================] - 0s 2ms/step
# f1_score =  0.999069561330242
# 0.9990695510583857
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2122
#            1       1.00      1.00      1.00      2177
#
#     accuracy                           1.00      4299
#    macro avg       1.00      1.00      1.00      4299
# weighted avg       1.00      1.00      1.00      4299
# <Axes: >

# %% [markdown]
# <h1> CNN 2 </h1>

# %%
# Model 2
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(n_timesteps,n_features)))
model.add(Dropout(0.5))
model.add(MaxPooling1D(pool_size=2))

model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(Dropout(0.5))
model.add(MaxPooling1D(pool_size=2))

model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dense(n_outputs, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 198, 64)           640
#
#  dropout_2 (Dropout)         (None, 198, 64)           0
#
#  max_pooling1d_2 (MaxPoolin  (None, 99, 64)            0
#  g1D)
#
#  conv1d_3 (Conv1D)           (None, 97, 64)            12352
#
#  dropout_3 (Dropout)         (None, 97, 64)            0
#
#  max_pooling1d_3 (MaxPoolin  (None, 48, 64)            0
#  g1D)
#
#  flatten_2 (Flatten)         (None, 3072)              0
#
#  dense_4 (Dense)             (None, 128)               393344
#
#  dense_5 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 406594 (1.55 MB)
# Trainable params: 406594 (1.55 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# validation_split = 0.1
batch_size = 128

train_epochs = 10
history = model.fit(X_train, y_train_hot, epochs=train_epochs, batch_size=batch_size, verbose=True,  validation_data = (X_val, y_val_hot), shuffle=True)
# Out:
# Epoch 1/10
# 108/108 [==============================] - 4s 14ms/step - loss: 0.4683 - accuracy: 0.9123 - val_loss: 0.0263 - val_accuracy: 0.9980
# Epoch 2/10
# 108/108 [==============================] - 1s 8ms/step - loss: 0.0065 - accuracy: 0.9988 - val_loss: 0.0178 - val_accuracy: 0.9977
# Epoch 3/10
# 108/108 [==============================] - 1s 9ms/step - loss: 0.0064 - accuracy: 0.9988 - val_loss: 0.0125 - val_accuracy: 0.9980
# Epoch 4/10
# 108/108 [==============================] - 1s 8ms/step - loss: 0.0051 - accuracy: 0.9988 - val_loss: 0.0102 - val_accuracy: 0.9983
# Epoch 5/10
# 108/108 [==============================] - 1s 9ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 0.0092 - val_accuracy: 0.9983
# Epoch 6/10
# 108/108 [==============================] - 1s 11ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.0077 - val_accuracy: 0.9985
# Epoch 7/10
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0045 - val_accuracy: 0.9991
# Epoch 8/10
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.0089 - val_accuracy: 0.9980
# Epoch 9/10
# 108/108 [==============================] - 1s 9ms/step - loss: 9.5889e-04 - accuracy: 0.9996 - val_loss: 0.0078 - val_accuracy: 0.9980
# Epoch 10/10
# 108/108 [==============================] - 1s 8ms/step - loss: 0.0021 - accuracy: 0.9993 - val_loss: 0.0061 - val_accuracy: 0.9985

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Training and validation accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

y_pred=model.predict(X_test)
y_pred = np.argmax(y_pred, axis=-1)
y_true = np.argmax(y_test_hot, axis=-1)

LABELS = ['Walking''Standing']
cm=confusion_matrix(y_true,y_pred)

#print(cm)
print('f1_score = ', f1_score(y_true, y_pred, average='weighted'))
print(accuracy_score(y_true,y_pred))
print(classification_report(y_true,y_pred))
sns.heatmap(cm, cmap="YlGnBu", xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt = '.2f')
# Out:
# 135/135 [==============================] - 1s 3ms/step
# f1_score =  0.9993021691850339
# 0.9993021632937893
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2122
#            1       1.00      1.00      1.00      2177
#
#     accuracy                           1.00      4299
#    macro avg       1.00      1.00      1.00      4299
# weighted avg       1.00      1.00      1.00      4299
# <Axes: >

# %% [markdown]
# <h1> CNN 3 </h1>

# %%
# Model 3
model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(n_timesteps,n_features)))
model.add(Dropout(0.5))
model.add(MaxPooling1D(pool_size=2))

model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(Dropout(0.5))
model.add(MaxPooling1D(pool_size=2))

model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
model.add(Dropout(0.5))
model.add(MaxPooling1D(pool_size=2))

model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dense(n_outputs, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_4 (Conv1D)           (None, 198, 64)           640
#
#  dropout_4 (Dropout)         (None, 198, 64)           0
#
#  max_pooling1d_4 (MaxPoolin  (None, 99, 64)            0
#  g1D)
#
#  conv1d_5 (Conv1D)           (None, 97, 64)            12352
#
#  dropout_5 (Dropout)         (None, 97, 64)            0
#
#  max_pooling1d_5 (MaxPoolin  (None, 48, 64)            0
#  g1D)
#
#  conv1d_6 (Conv1D)           (None, 46, 64)            12352
#
#  dropout_6 (Dropout)         (None, 46, 64)            0
#
#  max_pooling1d_6 (MaxPoolin  (None, 23, 64)            0
#  g1D)
#
#  flatten_3 (Flatten)         (None, 1472)              0
#
#  dense_6 (Dense)             (None, 128)               188544
#
#  dense_7 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 214146 (836.51 KB)
# Trainable params: 214146 (836.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# validation_split = 0.1
batch_size = 128

train_epochs = 10
history = model.fit(X_train, y_train_hot, epochs=train_epochs, batch_size=batch_size, verbose=True,  validation_data = (X_val, y_val_hot), shuffle=True)
# Out:
# Epoch 1/10
# 108/108 [==============================] - 4s 11ms/step - loss: 0.4994 - accuracy: 0.8960 - val_loss: 0.0231 - val_accuracy: 0.9971
# Epoch 2/10
# 108/108 [==============================] - 1s 8ms/step - loss: 0.0065 - accuracy: 0.9983 - val_loss: 0.0156 - val_accuracy: 0.9977
# Epoch 3/10
# 108/108 [==============================] - 1s 10ms/step - loss: 0.0061 - accuracy: 0.9985 - val_loss: 0.0158 - val_accuracy: 0.9980
# Epoch 4/10
# 108/108 [==============================] - 2s 15ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.0077 - val_accuracy: 0.9988
# Epoch 5/10
# 108/108 [==============================] - 2s 15ms/step - loss: 0.0049 - accuracy: 0.9985 - val_loss: 0.0088 - val_accuracy: 0.9994
# Epoch 6/10
# 108/108 [==============================] - 1s 12ms/step - loss: 0.0032 - accuracy: 0.9988 - val_loss: 0.0067 - val_accuracy: 0.9988
# Epoch 7/10
# 108/108 [==============================] - 1s 13ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0053 - val_accuracy: 0.9988
# Epoch 8/10
# 108/108 [==============================] - 1s 10ms/step - loss: 0.0019 - accuracy: 0.9993 - val_loss: 0.0048 - val_accuracy: 0.9988
# Epoch 9/10
# 108/108 [==============================] - 1s 11ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.0100 - val_accuracy: 0.9988
# Epoch 10/10
# 108/108 [==============================] - 1s 9ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.0062 - val_accuracy: 0.9994

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Training and validation accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

y_pred=model.predict(X_test)
y_pred = np.argmax(y_pred, axis=-1)
y_true = np.argmax(y_test_hot, axis=-1)

LABELS = ['Walking''Standing']
cm=confusion_matrix(y_true,y_pred)

#print(cm)
print('f1_score = ', f1_score(y_true, y_pred, average='weighted'))
print(accuracy_score(y_true,y_pred))
print(classification_report(y_true,y_pred))
sns.heatmap(cm, cmap="YlGnBu", xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt = '.2f')
# Out:
# 135/135 [==============================] - 1s 3ms/step
# f1_score =  0.9995347781978915
# 0.9995347755291928
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2122
#            1       1.00      1.00      1.00      2177
#
#     accuracy                           1.00      4299
#    macro avg       1.00      1.00      1.00      4299
# weighted avg       1.00      1.00      1.00      4299
# <Axes: >
