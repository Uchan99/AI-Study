# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# cnn model vary kernel size
from numpy import mean
from numpy import std
from numpy import dstack
from pandas import read_csv
from matplotlib import pyplot

from tensorflow.keras.utils import to_categorical
import tensorflow.keras
from sklearn.metrics import precision_score, recall_score, f1_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dense, Dropout, Flatten, Reshape, LSTM, Conv1D, MaxPooling1D, Bidirectional
from tensorflow.keras.layers import Input, TimeDistributed, Conv1D, MaxPooling1D, BatchNormalization, Activation, UpSampling1D
from tensorflow.keras.layers import add, multiply, GlobalAveragePooling1D
from keras import  backend as K

# %%
from typing import Any, Dict, List, Tuple
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns


def load_file(filepath):
    dataframe = pd.read_csv(filepath, header=None, delim_whitespace=True)
    return dataframe.values



# load a list of files and return as a 3d numpy array
def load_group(filenames, prefix=''):
    loaded = list()
    for name in filenames:
        data = load_file(prefix + name)
        loaded.append(data)
    # stack group so that features are the 3rd dimension
    loaded = np.dstack(loaded)
    return loaded

# load a dataset group, such as train or test
def load_dataset_group(group, prefix=''):
    filepath = prefix + group + '/Inertial Signals/'
    # load all 9 files as a single array
    filenames = list()
    # total acceleration
    filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
    # body acceleration
    filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
    # body gyroscope
    filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
    # load input data
    X = load_group(filenames, filepath)
    # load class output
    y = load_file(prefix + group + '/y_'+group+'.txt')
    return X, y


# load the dataset, returns train and test X and y elements
# load the dataset, returns train and test X and y elements
def load_dataset(prefix=''):
    # load all train
    trainX, trainy = load_dataset_group('train', prefix + '/content/drive/MyDrive/UCI HAR Dataset/')
    # load all test
    testX, testy = load_dataset_group('test', prefix + '/content/drive/MyDrive/UCI HAR Dataset/')

    #zero-offset class values
    trainy = trainy - 1
    testy = testy - 1

    trainy_one_hot = to_categorical(trainy)
    testy_one_hot = to_categorical(testy)
    print(trainX.shape, trainy.shape, trainy_one_hot.shape, testX.shape, testy.shape, testy_one_hot.shape)
    return trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot

# %%
trainX, trainy, trainy_one_hot, testX, testy, testy_one_hot = load_dataset()
# Out:
# (7352, 128, 9) (7352, 1) (7352, 6) (2947, 128, 9) (2947, 1) (2947, 6)

# %%
from sklearn.preprocessing import StandardScaler

def scale_data(trainX, testX):
 # remove overlap
 cut = int(trainX.shape[1] / 2)
 longX = trainX[:, -cut:, :]
 # flatten windows
 longX = longX.reshape((longX.shape[0] * longX.shape[1], longX.shape[2]))
 # flatten train and test
 flatTrainX = trainX.reshape((trainX.shape[0] * trainX.shape[1], trainX.shape[2]))
 flatTestX = testX.reshape((testX.shape[0] * testX.shape[1], testX.shape[2]))

 s = StandardScaler()
 # fit on training data
 s.fit(longX)
 # apply to training and test data
 longX = s.transform(longX)
 flatTrainX = s.transform(flatTrainX)
 flatTestX = s.transform(flatTestX)
 # reshape
 flatTrainX = flatTrainX.reshape((trainX.shape))
 flatTestX = flatTestX.reshape((testX.shape))
 return flatTrainX, flatTestX

# %%
trainX, testX = scale_data(trainX, testX)

# %%
print("X train shape: ", trainX.shape)
print("Y train shape: ", trainy.shape)
print("Y train One hot shape: ", trainy_one_hot.shape)
print("X test shape: ", testX.shape)
print("Y test shape: ", testy.shape)
print("Y test One hot shape: ", testy_one_hot.shape)
# Out:
# X train shape:  (7352, 128, 9)
# Y train shape:  (7352, 1)
# Y train One hot shape:  (7352, 6)
# X test shape:  (2947, 128, 9)
# Y test shape:  (2947, 1)
# Y test One hot shape:  (2947, 6)

# %%
print("0: Walking:" ,np.where(trainy == 0)[0].size)
print("1: WU:" ,np.where(trainy == 1)[0].size)
print("2: WD:" ,np.where(trainy == 2)[0].size)
print("3: Sitting:" ,np.where(trainy == 3)[0].size)
print("4: Standing:" ,np.where(trainy == 4)[0].size)
print("5: Laying:" ,np.where(trainy == 5)[0].size)
# Out:
# 0: Walking: 1226
# 1: WU: 1073
# 2: WD: 986
# 3: Sitting: 1286
# 4: Standing: 1374
# 5: Laying: 1407

# %%
X_train_all = trainX   # at this stage, the data includes both dynamic and static HAR data
y_train_all = trainy

X_test_all = testX
y_test_all = testy

# %%
import random

static_1 = np.where(trainy == 3)[0]
static_2 = np.where(trainy == 4)[0]
static_3 = np.where(trainy == 5)[0]
static = np.concatenate([static_1, static_2, static_3])
static_list = static.tolist()

# Shuffle dynamic data index
r = random.random()
random.shuffle(static_list, lambda: r)

static = np.array(static)

trainX = X_train_all[static]
trainy = y_train_all[static]
# Out:
# <ipython-input-11-9dd469a3f9cb>:11: DeprecationWarning: The *random* parameter to shuffle() has been deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   random.shuffle(static_list, lambda: r)

# %%
static_1 = np.where(testy == 3)[0]
static_2 = np.where(testy == 4)[0]
static_3 = np.where(testy == 5)[0]
static = np.concatenate([static_1, static_2, static_3])
static_list = static.tolist()

r = random.random()
random.shuffle(static_list, lambda: r)

static = np.array(static_list)

testX = X_test_all[static]
testy = y_test_all[static]
# Out:
# <ipython-input-12-f391b7cb3b7b>:8: DeprecationWarning: The *random* parameter to shuffle() has been deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   random.shuffle(static_list, lambda: r)

# %%
unique, counts = np.unique(trainy, return_counts=True)
print ("Train data label statistics::")
print (np.asarray((unique, counts)).T)

unique, counts = np.unique(testy, return_counts=True)
print ("Test data label statistics::")
print (np.asarray((unique, counts)).T)
# Out:
# Train data label statistics::
# [[   3 1286]
#  [   4 1374]
#  [   5 1407]]
# Test data label statistics::
# [[  3 491]
#  [  4 532]
#  [  5 537]]

# %%
trainy = trainy - 3
testy = testy - 3
trainy_one_hot = to_categorical(trainy)
testy_one_hot = to_categorical(testy)

# %%
print("X train shape: ", trainX.shape)
print("Y train shape: ", trainy.shape)
print("Y train One hot shape: ", trainy_one_hot.shape)
print("X test shape: ", testX.shape)
print("Y test shape: ", testy.shape)
print("Y test One hot shape: ", testy_one_hot.shape)
# Out:
# X train shape:  (4067, 128, 9)
# Y train shape:  (4067, 1)
# Y train One hot shape:  (4067, 3)
# X test shape:  (1560, 128, 9)
# Y test shape:  (1560, 1)
# Y test One hot shape:  (1560, 3)

# %%
def class_breakdown(data):
    # convert the numpy array into a dataframe
    df = pd.DataFrame(data)
    # group data by the class value and calculate the number of rows
    counts = df.groupby(0).size()
    # retrieve raw rows
    counts = counts.values
    # summarize
    for i in range(len(counts)):
        percent = counts[i] / len(df) * 100
        print('Class=%d, total=%d, percentage=%.3f' % (i+1, counts[i], percent))

# %%
from sklearn.model_selection import train_test_split
X_train,X_val,y_train_one_hot,y_val_one_hot,y_train,y_val=train_test_split(trainX, trainy_one_hot, trainy,test_size=0.3,random_state=100)

# %%
n_timesteps, n_features, n_outputs = trainX.shape[1], trainX.shape[2], trainy_one_hot.shape[1]

# %%
class_breakdown(y_train)
# Out:
# Class=1, total=877, percentage=30.815
# Class=2, total=972, percentage=34.153
# Class=3, total=997, percentage=35.032

# %% [markdown]
# <h1>Traning</h1>

# %%
def conv_block(in_x, nb_filter, kernel_size):

    x = Conv1D(nb_filter, kernel_size, padding='same')(in_x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    return x

# %%
def convolutional_block(in_x, nb_filters, stride):

    F1, F2, F3 = nb_filters

    x = in_x

    x = Conv1D(F1, 3, strides=stride,  padding='same', kernel_initializer="he_normal")(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv1D(F2, 3, strides=1, padding='same', kernel_initializer="he_normal")(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv1D(F3, 1, strides=1, padding='same', kernel_initializer="he_normal")(x)
    x = BatchNormalization()(x)

    #----------------------------------------------

    x1 = Conv1D(F3, 1, strides=stride, padding='same', kernel_initializer="he_normal")(in_x)
    x1 = BatchNormalization()(x1)

    x = add([x, x1])
    x = Activation('relu')(x)

    return x

# %%
# SE block은 채널 마다 가중치를 주어 합성곱을 수행
# 채널 간의 의존성을 고려하여 효과적인 특성 강조를 수행하는 방법 동입
# squeeze : Global average pooling을 사용하여 채널별로 평균값을 계산하여 각 채널의 중요도를 파악한다.
# excitation : Fully connected layer , 활성화함수를 통해서 각 채널의 가중치 조정, 채널 같의 관계 모델링
def se_block(in_x, nb_filter):
        # GAP층 사용하여 (특징 맵에서 각 채널의 평균으로 축소)
        squeeze = GlobalAveragePooling1D()(in_x)
        # flatten 층 없이 cnn의 특성 맵을 직접 dense층에 입력 -> 공간 정보를 유지한 채로 전달한다.
        excitation = Dense(units=nb_filter // 2)(squeeze)
        # 필터의 개수는 입력 -> 출력에서 얼마다 다운샘플링 하는지 비율을 뜻한다.
        excitation = Activation('relu')(excitation)
        excitation = Dense(units=nb_filter)(excitation)
        excitation = Activation('sigmoid')(excitation)
        excitation = Reshape((1,nb_filter))(excitation)
        # 처음 필터의 개수 ( 채널 수)로 reshape하여 각 채널의 중요도(가중치)를 채널에 곱하는 연산을 수행
        scale = multiply([in_x,excitation])
        out = add([in_x, scale])

        return out

# %%
def SENET():

    inputs = Input(shape=(n_timesteps,n_features))
    # (none, 128, 9)
    x = Conv1D(16, 32, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = se_block(x, 16)
    x = MaxPooling1D(4)(x)

    x = Conv1D(32, 16, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = se_block(x, 32)
    x = MaxPooling1D(4)(x)

    x = Flatten()(x)
    x = Dense(128,  activation='relu')(x)
    x = Dense(n_outputs,  activation='softmax')(x)

    model = keras.Model(inputs, x)

    return model

# %%
model = SENET()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 9)]             0         []
#
#  conv1d (Conv1D)             (None, 128, 16)              4624      ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 128, 16)              64        ['conv1d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 128, 16)              0         ['batch_normalization[0][0]']
#
#  global_average_pooling1d (  (None, 16)                   0         ['activation[0][0]']
#  GlobalAveragePooling1D)
#
#  dense (Dense)               (None, 8)                    136       ['global_average_pooling1d[0][
#                                                                     0]']
#
#  activation_1 (Activation)   (None, 8)                    0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 16)                   144       ['activation_1[0][0]']
#
#  activation_2 (Activation)   (None, 16)                   0         ['dense_1[0][0]']
#
#  reshape (Reshape)           (None, 1, 16)                0         ['activation_2[0][0]']
#
#  multiply (Multiply)         (None, 128, 16)              0         ['activation[0][0]',
#                                                                      'reshape[0][0]']
#
#  add (Add)                   (None, 128, 16)              0         ['activation[0][0]',
#                                                                      'multiply[0][0]']
#
#  max_pooling1d (MaxPooling1  (None, 32, 16)               0         ['add[0][0]']
#  D)
#
#  conv1d_1 (Conv1D)           (None, 32, 32)               8224      ['max_pooling1d[0][0]']
#
#  batch_normalization_1 (Bat  (None, 32, 32)               128       ['conv1d_1[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 32, 32)               0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  global_average_pooling1d_1  (None, 32)                   0         ['activation_3[0][0]']
#   (GlobalAveragePooling1D)
#
#  dense_2 (Dense)             (None, 16)                   528       ['global_average_pooling1d_1[0
#                                                                     ][0]']
#
#  activation_4 (Activation)   (None, 16)                   0         ['dense_2[0][0]']
#
#  dense_3 (Dense)             (None, 32)                   544       ['activation_4[0][0]']
#
#  activation_5 (Activation)   (None, 32)                   0         ['dense_3[0][0]']
#
#  reshape_1 (Reshape)         (None, 1, 32)                0         ['activation_5[0][0]']
#
#  multiply_1 (Multiply)       (None, 32, 32)               0         ['activation_3[0][0]',
#                                                                      'reshape_1[0][0]']
#
#  add_1 (Add)                 (None, 32, 32)               0         ['activation_3[0][0]',
#                                                                      'multiply_1[0][0]']
#
#  max_pooling1d_1 (MaxPoolin  (None, 8, 32)                0         ['add_1[0][0]']
#  g1D)
#
#  flatten (Flatten)           (None, 256)                  0         ['max_pooling1d_1[0][0]']
#
#  dense_4 (Dense)             (None, 128)                  32896     ['flatten[0][0]']
#
#  dense_5 (Dense)             (None, 3)                    387       ['dense_4[0][0]']
#
# ==================================================================================================
# Total params: 47675 (186.23 KB)
# Trainable params: 47579 (185.86 KB)
# Non-trainable params: 96 (384.00 Byte)
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True)

# %%
# validation_split = 0.1
batch_size = 32

train_epochs = 100
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(trainX, trainy_one_hot, epochs=train_epochs, batch_size=batch_size, verbose=True,  validation_data = (X_val, y_val_one_hot), shuffle=True)
# Out:
# Epoch 1/100
# 128/128 [==============================] - 8s 20ms/step - loss: 0.2657 - accuracy: 0.8925 - val_loss: 0.2070 - val_accuracy: 0.9050
# Epoch 2/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.2290 - accuracy: 0.9007 - val_loss: 0.2371 - val_accuracy: 0.9083
# Epoch 3/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.2340 - accuracy: 0.9024 - val_loss: 0.2106 - val_accuracy: 0.9156
# Epoch 4/100
# 128/128 [==============================] - 3s 25ms/step - loss: 0.2260 - accuracy: 0.9031 - val_loss: 0.1959 - val_accuracy: 0.9140
# Epoch 5/100
# 128/128 [==============================] - 3s 24ms/step - loss: 0.2053 - accuracy: 0.9127 - val_loss: 0.1806 - val_accuracy: 0.9271
# Epoch 6/100
# 128/128 [==============================] - 3s 27ms/step - loss: 0.2079 - accuracy: 0.9090 - val_loss: 0.1768 - val_accuracy: 0.9287
# Epoch 7/100
# 128/128 [==============================] - 4s 31ms/step - loss: 0.2010 - accuracy: 0.9169 - val_loss: 0.1945 - val_accuracy: 0.9214
# Epoch 8/100
# 128/128 [==============================] - 6s 45ms/step - loss: 0.2024 - accuracy: 0.9174 - val_loss: 0.1769 - val_accuracy: 0.9197
# Epoch 9/100
# 128/128 [==============================] - 5s 43ms/step - loss: 0.1836 - accuracy: 0.9243 - val_loss: 0.1872 - val_accuracy: 0.9181
# Epoch 10/100
# 128/128 [==============================] - 4s 32ms/step - loss: 0.1885 - accuracy: 0.9253 - val_loss: 0.1870 - val_accuracy: 0.9214
# Epoch 11/100
# 128/128 [==============================] - 4s 30ms/step - loss: 0.1645 - accuracy: 0.9277 - val_loss: 0.1605 - val_accuracy: 0.9279
# Epoch 12/100
# 128/128 [==============================] - 5s 38ms/step - loss: 0.1639 - accuracy: 0.9314 - val_loss: 0.1499 - val_accuracy: 0.9320
# Epoch 13/100
# 128/128 [==============================] - 4s 31ms/step - loss: 0.2007 - accuracy: 0.9186 - val_loss: 0.1552 - val_accuracy: 0.9263
# Epoch 14/100
# 128/128 [==============================] - 3s 24ms/step - loss: 0.1655 - accuracy: 0.9329 - val_loss: 0.1551 - val_accuracy: 0.9361
# Epoch 15/100
# 128/128 [==============================] - 4s 32ms/step - loss: 0.1645 - accuracy: 0.9302 - val_loss: 0.1490 - val_accuracy: 0.9378
# Epoch 16/100
# 128/128 [==============================] - 6s 45ms/step - loss: 0.1923 - accuracy: 0.9218 - val_loss: 0.1770 - val_accuracy: 0.9304
# Epoch 17/100
# 128/128 [==============================] - 5s 37ms/step - loss: 0.1546 - accuracy: 0.9324 - val_loss: 0.1323 - val_accuracy: 0.9451
# Epoch 18/100
# 128/128 [==============================] - 4s 34ms/step - loss: 0.1451 - accuracy: 0.9449 - val_loss: 0.1310 - val_accuracy: 0.9402
# Epoch 19/100
# 128/128 [==============================] - 7s 52ms/step - loss: 0.1455 - accuracy: 0.9427 - val_loss: 0.1397 - val_accuracy: 0.9279
# Epoch 20/100
# 128/128 [==============================] - 4s 27ms/step - loss: 0.1502 - accuracy: 0.9380 - val_loss: 0.1253 - val_accuracy: 0.9509
# Epoch 21/100
# 128/128 [==============================] - 4s 30ms/step - loss: 0.1317 - accuracy: 0.9434 - val_loss: 0.1272 - val_accuracy: 0.9517
# Epoch 22/100
# 128/128 [==============================] - 4s 27ms/step - loss: 0.1293 - accuracy: 0.9471 - val_loss: 0.1074 - val_accuracy: 0.9623
# Epoch 23/100
# 128/128 [==============================] - 4s 33ms/step - loss: 0.1247 - accuracy: 0.9486 - val_loss: 0.1036 - val_accuracy: 0.9664
# Epoch 24/100
# 128/128 [==============================] - 3s 27ms/step - loss: 0.1223 - accuracy: 0.9525 - val_loss: 0.1047 - val_accuracy: 0.9582
# Epoch 25/100
# 128/128 [==============================] - 3s 25ms/step - loss: 0.1276 - accuracy: 0.9491 - val_loss: 0.1016 - val_accuracy: 0.9607
# Epoch 26/100
# 128/128 [==============================] - 3s 23ms/step - loss: 0.1277 - accuracy: 0.9493 - val_loss: 0.1124 - val_accuracy: 0.9550
# Epoch 27/100
# 128/128 [==============================] - 3s 24ms/step - loss: 0.1202 - accuracy: 0.9528 - val_loss: 0.1043 - val_accuracy: 0.9574
# Epoch 28/100
# 128/128 [==============================] - 3s 21ms/step - loss: 0.1151 - accuracy: 0.9580 - val_loss: 0.0928 - val_accuracy: 0.9672
# Epoch 29/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.1274 - accuracy: 0.9457 - val_loss: 0.0971 - val_accuracy: 0.9566
# Epoch 30/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.1097 - accuracy: 0.9567 - val_loss: 0.0954 - val_accuracy: 0.9640
# Epoch 31/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.1050 - accuracy: 0.9577 - val_loss: 0.0819 - val_accuracy: 0.9664
# Epoch 32/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.1083 - accuracy: 0.9575 - val_loss: 0.0986 - val_accuracy: 0.9631
# Epoch 33/100
# 128/128 [==============================] - 3s 24ms/step - loss: 0.1109 - accuracy: 0.9582 - val_loss: 0.0941 - val_accuracy: 0.9640
# Epoch 34/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.0982 - accuracy: 0.9602 - val_loss: 0.0840 - val_accuracy: 0.9738
# Epoch 35/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0913 - accuracy: 0.9641 - val_loss: 0.0830 - val_accuracy: 0.9664
# Epoch 36/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0933 - accuracy: 0.9631 - val_loss: 0.0751 - val_accuracy: 0.9754
# Epoch 37/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0960 - accuracy: 0.9607 - val_loss: 0.0775 - val_accuracy: 0.9722
# Epoch 38/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0862 - accuracy: 0.9646 - val_loss: 0.0677 - val_accuracy: 0.9705
# Epoch 39/100
# 128/128 [==============================] - 3s 25ms/step - loss: 0.0831 - accuracy: 0.9656 - val_loss: 0.0619 - val_accuracy: 0.9754
# Epoch 40/100
# 128/128 [==============================] - 3s 20ms/step - loss: 0.1068 - accuracy: 0.9577 - val_loss: 0.1603 - val_accuracy: 0.9378
# Epoch 41/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.1012 - accuracy: 0.9580 - val_loss: 0.0874 - val_accuracy: 0.9689
# Epoch 42/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0986 - accuracy: 0.9631 - val_loss: 0.0847 - val_accuracy: 0.9689
# Epoch 43/100
# 128/128 [==============================] - 3s 23ms/step - loss: 0.0736 - accuracy: 0.9727 - val_loss: 0.0548 - val_accuracy: 0.9795
# Epoch 44/100
# 128/128 [==============================] - 3s 20ms/step - loss: 0.0673 - accuracy: 0.9732 - val_loss: 0.0554 - val_accuracy: 0.9812
# Epoch 45/100
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0656 - accuracy: 0.9744 - val_loss: 0.0763 - val_accuracy: 0.9648
# Epoch 46/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0542 - accuracy: 0.9774 - val_loss: 0.0673 - val_accuracy: 0.9754
# Epoch 47/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0610 - accuracy: 0.9769 - val_loss: 0.0411 - val_accuracy: 0.9820
# Epoch 48/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0640 - accuracy: 0.9757 - val_loss: 0.0936 - val_accuracy: 0.9590
# Epoch 49/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0971 - accuracy: 0.9619 - val_loss: 0.0580 - val_accuracy: 0.9762
# Epoch 50/100
# 128/128 [==============================] - 3s 21ms/step - loss: 0.0774 - accuracy: 0.9673 - val_loss: 0.0839 - val_accuracy: 0.9623
# Epoch 51/100
# 128/128 [==============================] - 3s 25ms/step - loss: 0.0887 - accuracy: 0.9643 - val_loss: 0.0647 - val_accuracy: 0.9738
# Epoch 52/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0553 - accuracy: 0.9791 - val_loss: 0.0440 - val_accuracy: 0.9820
# Epoch 53/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0493 - accuracy: 0.9798 - val_loss: 0.0666 - val_accuracy: 0.9689
# Epoch 54/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0820 - accuracy: 0.9702 - val_loss: 0.0439 - val_accuracy: 0.9877
# Epoch 55/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0552 - accuracy: 0.9793 - val_loss: 0.0402 - val_accuracy: 0.9853
# Epoch 56/100
# 128/128 [==============================] - 4s 28ms/step - loss: 0.0718 - accuracy: 0.9734 - val_loss: 0.0369 - val_accuracy: 0.9828
# Epoch 57/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.0520 - accuracy: 0.9808 - val_loss: 0.0373 - val_accuracy: 0.9877
# Epoch 58/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0402 - accuracy: 0.9865 - val_loss: 0.0330 - val_accuracy: 0.9844
# Epoch 59/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0658 - accuracy: 0.9774 - val_loss: 0.0482 - val_accuracy: 0.9853
# Epoch 60/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0369 - accuracy: 0.9862 - val_loss: 0.0335 - val_accuracy: 0.9894
# Epoch 61/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0342 - accuracy: 0.9867 - val_loss: 0.0423 - val_accuracy: 0.9869
# Epoch 62/100
# 128/128 [==============================] - 3s 27ms/step - loss: 0.0363 - accuracy: 0.9867 - val_loss: 0.0240 - val_accuracy: 0.9918
# Epoch 63/100
# 128/128 [==============================] - 4s 29ms/step - loss: 0.0317 - accuracy: 0.9882 - val_loss: 0.0283 - val_accuracy: 0.9885
# Epoch 64/100
# 128/128 [==============================] - 3s 21ms/step - loss: 0.0354 - accuracy: 0.9840 - val_loss: 0.0324 - val_accuracy: 0.9894
# Epoch 65/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0371 - accuracy: 0.9872 - val_loss: 0.0582 - val_accuracy: 0.9795
# Epoch 66/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0327 - accuracy: 0.9860 - val_loss: 0.0216 - val_accuracy: 0.9918
# Epoch 67/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0254 - accuracy: 0.9914 - val_loss: 0.0228 - val_accuracy: 0.9885
# Epoch 68/100
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0329 - accuracy: 0.9867 - val_loss: 0.0319 - val_accuracy: 0.9910
# Epoch 69/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.0794 - accuracy: 0.9690 - val_loss: 0.0286 - val_accuracy: 0.9877
# Epoch 70/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0385 - accuracy: 0.9862 - val_loss: 0.0296 - val_accuracy: 0.9918
# Epoch 71/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0224 - accuracy: 0.9921 - val_loss: 0.0213 - val_accuracy: 0.9934
# Epoch 72/100
# 128/128 [==============================] - 4s 29ms/step - loss: 0.0259 - accuracy: 0.9899 - val_loss: 0.0174 - val_accuracy: 0.9943
# Epoch 73/100
# 128/128 [==============================] - 3s 24ms/step - loss: 0.0219 - accuracy: 0.9909 - val_loss: 0.0151 - val_accuracy: 0.9967
# Epoch 74/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.0246 - accuracy: 0.9909 - val_loss: 0.0190 - val_accuracy: 0.9934
# Epoch 75/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0261 - accuracy: 0.9909 - val_loss: 0.0542 - val_accuracy: 0.9787
# Epoch 76/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0163 - accuracy: 0.9941 - val_loss: 0.0347 - val_accuracy: 0.9885
# Epoch 77/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0263 - accuracy: 0.9909 - val_loss: 0.0168 - val_accuracy: 0.9934
# Epoch 78/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0243 - accuracy: 0.9902 - val_loss: 0.0260 - val_accuracy: 0.9902
# Epoch 79/100
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0247 - accuracy: 0.9904 - val_loss: 0.0097 - val_accuracy: 0.9984
# Epoch 80/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.0198 - accuracy: 0.9931 - val_loss: 0.0203 - val_accuracy: 0.9934
# Epoch 81/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0174 - accuracy: 0.9951 - val_loss: 0.0281 - val_accuracy: 0.9894
# Epoch 82/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0347 - accuracy: 0.9902 - val_loss: 0.0240 - val_accuracy: 0.9951
# Epoch 83/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0910 - accuracy: 0.9717 - val_loss: 0.0259 - val_accuracy: 0.9918
# Epoch 84/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.0349 - accuracy: 0.9877 - val_loss: 0.0246 - val_accuracy: 0.9910
# Epoch 85/100
# 128/128 [==============================] - 3s 25ms/step - loss: 0.0226 - accuracy: 0.9911 - val_loss: 0.0112 - val_accuracy: 0.9975
# Epoch 86/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.0197 - accuracy: 0.9946 - val_loss: 0.0115 - val_accuracy: 0.9967
# Epoch 87/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0161 - accuracy: 0.9951 - val_loss: 0.0113 - val_accuracy: 0.9975
# Epoch 88/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0233 - accuracy: 0.9924 - val_loss: 0.0087 - val_accuracy: 0.9992
# Epoch 89/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0400 - accuracy: 0.9862 - val_loss: 0.0186 - val_accuracy: 0.9943
# Epoch 90/100
# 128/128 [==============================] - 3s 20ms/step - loss: 0.0263 - accuracy: 0.9904 - val_loss: 0.0128 - val_accuracy: 0.9943
# Epoch 91/100
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0139 - accuracy: 0.9953 - val_loss: 0.0080 - val_accuracy: 0.9992
# Epoch 92/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0475 - accuracy: 0.9833 - val_loss: 0.0162 - val_accuracy: 0.9959
# Epoch 93/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0176 - accuracy: 0.9948 - val_loss: 0.0229 - val_accuracy: 0.9902
# Epoch 94/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0948 - accuracy: 0.9727 - val_loss: 0.0153 - val_accuracy: 0.9959
# Epoch 95/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0185 - accuracy: 0.9953 - val_loss: 0.0108 - val_accuracy: 0.9975
# Epoch 96/100
# 128/128 [==============================] - 3s 21ms/step - loss: 0.0139 - accuracy: 0.9953 - val_loss: 0.0132 - val_accuracy: 0.9951
# Epoch 97/100
# 128/128 [==============================] - 4s 29ms/step - loss: 0.0120 - accuracy: 0.9958 - val_loss: 0.0092 - val_accuracy: 0.9975
# Epoch 98/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0100 - accuracy: 0.9968 - val_loss: 0.0126 - val_accuracy: 0.9975
# Epoch 99/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0091 - accuracy: 0.9975 - val_loss: 0.0061 - val_accuracy: 0.9967
# Epoch 100/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0097 - accuracy: 0.9961 - val_loss: 0.0046 - val_accuracy: 1.0000

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Training and validation accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'Validation'], loc='upper left')

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

predy=model.predict(testX)
predy=np.argmax(predy, axis=-1)
LABELS = ['SITTING','STANDIND','LAYING']
cm=confusion_matrix(testy,predy)
print(cm)
print(accuracy_score(testy,predy))
print(f1_score(testy,predy, average='weighted'))
print(classification_report(testy,predy))
sns.heatmap(cm, cmap="YlGnBu", xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt = '.2f')
# Out:
# 49/49 [==============================] - 1s 6ms/step
# [[428  63   0]
#  [ 19 513   0]
#  [  0   0 537]]
# 0.9474358974358974
# 0.9472467422478198
#               precision    recall  f1-score   support
#
#            0       0.96      0.87      0.91       491
#            1       0.89      0.96      0.93       532
#            2       1.00      1.00      1.00       537
#
#     accuracy                           0.95      1560
#    macro avg       0.95      0.95      0.95      1560
# weighted avg       0.95      0.95      0.95      1560
# <Axes: >

# %%
def en_loss(y_true, y_pred):

    epsilon = 1.e-7
    gamma = float(0.3)

    y_true = tf.cast(y_true, tf.float32)
    # 텐서의 데이터 타입 변경
    y_pred = tf.clip_by_value(y_pred, epsilon, 1. - epsilon)
    # 텐서의 값을 지정된 범위로 제한. : y_pred의 값을 epsilon과 1. - epsilon 사이
    pos_pred = tf.pow(-tf.math.log(y_pred),gamma)
    nag_pred = tf.pow(-tf.math.log(1-y_pred),gamma)
    y_t = tf.multiply(y_true, pos_pred) + tf.multiply(1-y_true, nag_pred)
    en_loss = tf.reduce_mean(y_t)
    return en_loss

# %%
model = SENET()
model.summary()
model.compile(optimizer = 'adam', loss=en_loss, metrics = ["accuracy"])
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 128, 9)]             0         []
#
#  conv1d_2 (Conv1D)           (None, 128, 16)              4624      ['input_2[0][0]']
#
#  batch_normalization_2 (Bat  (None, 128, 16)              64        ['conv1d_2[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 128, 16)              0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  global_average_pooling1d_2  (None, 16)                   0         ['activation_6[0][0]']
#   (GlobalAveragePooling1D)
#
#  dense_6 (Dense)             (None, 8)                    136       ['global_average_pooling1d_2[0
#                                                                     ][0]']
#
#  activation_7 (Activation)   (None, 8)                    0         ['dense_6[0][0]']
#
#  dense_7 (Dense)             (None, 16)                   144       ['activation_7[0][0]']
#
#  activation_8 (Activation)   (None, 16)                   0         ['dense_7[0][0]']
#
#  reshape_2 (Reshape)         (None, 1, 16)                0         ['activation_8[0][0]']
#
#  multiply_2 (Multiply)       (None, 128, 16)              0         ['activation_6[0][0]',
#                                                                      'reshape_2[0][0]']
#
#  add_2 (Add)                 (None, 128, 16)              0         ['activation_6[0][0]',
#                                                                      'multiply_2[0][0]']
#
#  max_pooling1d_2 (MaxPoolin  (None, 32, 16)               0         ['add_2[0][0]']
#  g1D)
#
#  conv1d_3 (Conv1D)           (None, 32, 32)               8224      ['max_pooling1d_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 32, 32)               128       ['conv1d_3[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 32, 32)               0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  global_average_pooling1d_3  (None, 32)                   0         ['activation_9[0][0]']
#   (GlobalAveragePooling1D)
#
#  dense_8 (Dense)             (None, 16)                   528       ['global_average_pooling1d_3[0
#                                                                     ][0]']
#
#  activation_10 (Activation)  (None, 16)                   0         ['dense_8[0][0]']
#
#  dense_9 (Dense)             (None, 32)                   544       ['activation_10[0][0]']
#
#  activation_11 (Activation)  (None, 32)                   0         ['dense_9[0][0]']
#
#  reshape_3 (Reshape)         (None, 1, 32)                0         ['activation_11[0][0]']
#
#  multiply_3 (Multiply)       (None, 32, 32)               0         ['activation_9[0][0]',
#                                                                      'reshape_3[0][0]']
#
#  add_3 (Add)                 (None, 32, 32)               0         ['activation_9[0][0]',
#                                                                      'multiply_3[0][0]']
#
#  max_pooling1d_3 (MaxPoolin  (None, 8, 32)                0         ['add_3[0][0]']
#  g1D)
#
#  flatten_1 (Flatten)         (None, 256)                  0         ['max_pooling1d_3[0][0]']
#
#  dense_10 (Dense)            (None, 128)                  32896     ['flatten_1[0][0]']
#
#  dense_11 (Dense)            (None, 3)                    387       ['dense_10[0][0]']
#
# ==================================================================================================
# Total params: 47675 (186.23 KB)
# Trainable params: 47579 (185.86 KB)
# Non-trainable params: 96 (384.00 Byte)
# __________________________________________________________________________________________________

# %%
# validation_split = 0.1
batch_size = 32

train_epochs = 100
history = model.fit(trainX, trainy_one_hot, epochs=train_epochs, batch_size=batch_size, verbose=True,  validation_data = (X_val, y_val_one_hot), shuffle=True)
# Out:
# Epoch 1/100
# 128/128 [==============================] - 6s 19ms/step - loss: 0.1822 - accuracy: 0.8798 - val_loss: 0.1417 - val_accuracy: 0.8993
# Epoch 2/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.1498 - accuracy: 0.8982 - val_loss: 0.1251 - val_accuracy: 0.9255
# Epoch 3/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.1470 - accuracy: 0.9009 - val_loss: 0.1252 - val_accuracy: 0.9238
# Epoch 4/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.1393 - accuracy: 0.9088 - val_loss: 0.1286 - val_accuracy: 0.9066
# Epoch 5/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.1426 - accuracy: 0.9014 - val_loss: 0.1373 - val_accuracy: 0.9009
# Epoch 6/100
# 128/128 [==============================] - 3s 24ms/step - loss: 0.1351 - accuracy: 0.9100 - val_loss: 0.1182 - val_accuracy: 0.9214
# Epoch 7/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.1260 - accuracy: 0.9176 - val_loss: 0.1253 - val_accuracy: 0.9165
# Epoch 8/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.1250 - accuracy: 0.9162 - val_loss: 0.1319 - val_accuracy: 0.9042
# Epoch 9/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.1249 - accuracy: 0.9169 - val_loss: 0.1081 - val_accuracy: 0.9279
# Epoch 10/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.1190 - accuracy: 0.9216 - val_loss: 0.1108 - val_accuracy: 0.9263
# Epoch 11/100
# 128/128 [==============================] - 3s 26ms/step - loss: 0.1159 - accuracy: 0.9253 - val_loss: 0.1134 - val_accuracy: 0.9287
# Epoch 12/100
# 128/128 [==============================] - 3s 21ms/step - loss: 0.1139 - accuracy: 0.9240 - val_loss: 0.1060 - val_accuracy: 0.9304
# Epoch 13/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.1109 - accuracy: 0.9262 - val_loss: 0.1051 - val_accuracy: 0.9320
# Epoch 14/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.1034 - accuracy: 0.9331 - val_loss: 0.0975 - val_accuracy: 0.9337
# Epoch 15/100
# 128/128 [==============================] - 3s 20ms/step - loss: 0.1078 - accuracy: 0.9312 - val_loss: 0.0946 - val_accuracy: 0.9378
# Epoch 16/100
# 128/128 [==============================] - 3s 20ms/step - loss: 0.0987 - accuracy: 0.9368 - val_loss: 0.0856 - val_accuracy: 0.9451
# Epoch 17/100
# 128/128 [==============================] - 3s 27ms/step - loss: 0.1046 - accuracy: 0.9321 - val_loss: 0.0978 - val_accuracy: 0.9353
# Epoch 18/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.1069 - accuracy: 0.9334 - val_loss: 0.1084 - val_accuracy: 0.9271
# Epoch 19/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.1186 - accuracy: 0.9211 - val_loss: 0.1045 - val_accuracy: 0.9394
# Epoch 20/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0892 - accuracy: 0.9439 - val_loss: 0.0895 - val_accuracy: 0.9394
# Epoch 21/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0923 - accuracy: 0.9395 - val_loss: 0.0875 - val_accuracy: 0.9459
# Epoch 22/100
# 128/128 [==============================] - 3s 21ms/step - loss: 0.0879 - accuracy: 0.9427 - val_loss: 0.0923 - val_accuracy: 0.9443
# Epoch 23/100
# 128/128 [==============================] - 3s 25ms/step - loss: 0.1003 - accuracy: 0.9356 - val_loss: 0.0810 - val_accuracy: 0.9476
# Epoch 24/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0930 - accuracy: 0.9383 - val_loss: 0.0810 - val_accuracy: 0.9468
# Epoch 25/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0834 - accuracy: 0.9464 - val_loss: 0.0776 - val_accuracy: 0.9492
# Epoch 26/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.0813 - accuracy: 0.9498 - val_loss: 0.0689 - val_accuracy: 0.9550
# Epoch 27/100
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0876 - accuracy: 0.9422 - val_loss: 0.0837 - val_accuracy: 0.9500
# Epoch 28/100
# 128/128 [==============================] - 4s 30ms/step - loss: 0.0776 - accuracy: 0.9508 - val_loss: 0.0691 - val_accuracy: 0.9574
# Epoch 29/100
# 128/128 [==============================] - 3s 20ms/step - loss: 0.0776 - accuracy: 0.9513 - val_loss: 0.0648 - val_accuracy: 0.9607
# Epoch 30/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0766 - accuracy: 0.9528 - val_loss: 0.0633 - val_accuracy: 0.9615
# Epoch 31/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0728 - accuracy: 0.9567 - val_loss: 0.0621 - val_accuracy: 0.9623
# Epoch 32/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0753 - accuracy: 0.9535 - val_loss: 0.0644 - val_accuracy: 0.9599
# Epoch 33/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0818 - accuracy: 0.9489 - val_loss: 0.0700 - val_accuracy: 0.9574
# Epoch 34/100
# 128/128 [==============================] - 3s 25ms/step - loss: 0.0723 - accuracy: 0.9545 - val_loss: 0.0570 - val_accuracy: 0.9672
# Epoch 35/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0732 - accuracy: 0.9555 - val_loss: 0.0586 - val_accuracy: 0.9672
# Epoch 36/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0716 - accuracy: 0.9557 - val_loss: 0.0552 - val_accuracy: 0.9697
# Epoch 37/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0757 - accuracy: 0.9540 - val_loss: 0.0675 - val_accuracy: 0.9566
# Epoch 38/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0732 - accuracy: 0.9545 - val_loss: 0.0672 - val_accuracy: 0.9607
# Epoch 39/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0694 - accuracy: 0.9557 - val_loss: 0.0599 - val_accuracy: 0.9648
# Epoch 40/100
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0654 - accuracy: 0.9589 - val_loss: 0.0522 - val_accuracy: 0.9722
# Epoch 41/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0677 - accuracy: 0.9577 - val_loss: 0.0542 - val_accuracy: 0.9697
# Epoch 42/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0640 - accuracy: 0.9624 - val_loss: 0.0469 - val_accuracy: 0.9730
# Epoch 43/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0637 - accuracy: 0.9621 - val_loss: 0.0602 - val_accuracy: 0.9640
# Epoch 44/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.0744 - accuracy: 0.9538 - val_loss: 0.0587 - val_accuracy: 0.9697
# Epoch 45/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0694 - accuracy: 0.9570 - val_loss: 0.0762 - val_accuracy: 0.9500
# Epoch 46/100
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0586 - accuracy: 0.9661 - val_loss: 0.0579 - val_accuracy: 0.9640
# Epoch 47/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.0570 - accuracy: 0.9663 - val_loss: 0.0457 - val_accuracy: 0.9738
# Epoch 48/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0558 - accuracy: 0.9680 - val_loss: 0.0399 - val_accuracy: 0.9795
# Epoch 49/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0533 - accuracy: 0.9700 - val_loss: 0.0600 - val_accuracy: 0.9648
# Epoch 50/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0638 - accuracy: 0.9609 - val_loss: 0.0451 - val_accuracy: 0.9754
# Epoch 51/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.0560 - accuracy: 0.9668 - val_loss: 0.0453 - val_accuracy: 0.9746
# Epoch 52/100
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0538 - accuracy: 0.9683 - val_loss: 0.0373 - val_accuracy: 0.9828
# Epoch 53/100
# 128/128 [==============================] - 3s 20ms/step - loss: 0.0483 - accuracy: 0.9727 - val_loss: 0.0413 - val_accuracy: 0.9762
# Epoch 54/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0519 - accuracy: 0.9695 - val_loss: 0.0435 - val_accuracy: 0.9746
# Epoch 55/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0518 - accuracy: 0.9698 - val_loss: 0.0408 - val_accuracy: 0.9787
# Epoch 56/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0521 - accuracy: 0.9702 - val_loss: 0.0408 - val_accuracy: 0.9787
# Epoch 57/100
# 128/128 [==============================] - 3s 23ms/step - loss: 0.0448 - accuracy: 0.9766 - val_loss: 0.0470 - val_accuracy: 0.9730
# Epoch 58/100
# 128/128 [==============================] - 3s 25ms/step - loss: 0.0517 - accuracy: 0.9717 - val_loss: 0.0382 - val_accuracy: 0.9779
# Epoch 59/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0462 - accuracy: 0.9747 - val_loss: 0.0332 - val_accuracy: 0.9844
# Epoch 60/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0535 - accuracy: 0.9690 - val_loss: 0.0315 - val_accuracy: 0.9861
# Epoch 61/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0502 - accuracy: 0.9710 - val_loss: 0.0326 - val_accuracy: 0.9820
# Epoch 62/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0501 - accuracy: 0.9717 - val_loss: 0.0354 - val_accuracy: 0.9820
# Epoch 63/100
# 128/128 [==============================] - 3s 24ms/step - loss: 0.0510 - accuracy: 0.9712 - val_loss: 0.0370 - val_accuracy: 0.9820
# Epoch 64/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.0467 - accuracy: 0.9744 - val_loss: 0.0313 - val_accuracy: 0.9853
# Epoch 65/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0458 - accuracy: 0.9747 - val_loss: 0.0377 - val_accuracy: 0.9787
# Epoch 66/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0441 - accuracy: 0.9764 - val_loss: 0.0302 - val_accuracy: 0.9861
# Epoch 67/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0404 - accuracy: 0.9791 - val_loss: 0.0295 - val_accuracy: 0.9869
# Epoch 68/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0475 - accuracy: 0.9720 - val_loss: 0.0357 - val_accuracy: 0.9812
# Epoch 69/100
# 128/128 [==============================] - 3s 24ms/step - loss: 0.0450 - accuracy: 0.9744 - val_loss: 0.0311 - val_accuracy: 0.9844
# Epoch 70/100
# 128/128 [==============================] - 3s 22ms/step - loss: 0.0416 - accuracy: 0.9771 - val_loss: 0.0325 - val_accuracy: 0.9844
# Epoch 71/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0375 - accuracy: 0.9813 - val_loss: 0.0345 - val_accuracy: 0.9828
# Epoch 72/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0451 - accuracy: 0.9749 - val_loss: 0.0300 - val_accuracy: 0.9877
# Epoch 73/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0414 - accuracy: 0.9784 - val_loss: 0.0579 - val_accuracy: 0.9656
# Epoch 74/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0368 - accuracy: 0.9816 - val_loss: 0.0394 - val_accuracy: 0.9803
# Epoch 75/100
# 128/128 [==============================] - 3s 24ms/step - loss: 0.0461 - accuracy: 0.9742 - val_loss: 0.0451 - val_accuracy: 0.9746
# Epoch 76/100
# 128/128 [==============================] - 3s 21ms/step - loss: 0.0366 - accuracy: 0.9813 - val_loss: 0.0295 - val_accuracy: 0.9869
# Epoch 77/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0424 - accuracy: 0.9774 - val_loss: 0.0336 - val_accuracy: 0.9844
# Epoch 78/100
# 128/128 [==============================] - 2s 16ms/step - loss: 0.0444 - accuracy: 0.9749 - val_loss: 0.0472 - val_accuracy: 0.9738
# Epoch 79/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0398 - accuracy: 0.9784 - val_loss: 0.0281 - val_accuracy: 0.9885
# Epoch 80/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0381 - accuracy: 0.9798 - val_loss: 0.0337 - val_accuracy: 0.9844
# Epoch 81/100
# 128/128 [==============================] - 3s 24ms/step - loss: 0.0361 - accuracy: 0.9825 - val_loss: 0.0284 - val_accuracy: 0.9877
# Epoch 82/100
# 128/128 [==============================] - 3s 21ms/step - loss: 0.0336 - accuracy: 0.9833 - val_loss: 0.0282 - val_accuracy: 0.9877
# Epoch 83/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0371 - accuracy: 0.9803 - val_loss: 0.0293 - val_accuracy: 0.9869
# Epoch 84/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0334 - accuracy: 0.9830 - val_loss: 0.0267 - val_accuracy: 0.9885
# Epoch 85/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0330 - accuracy: 0.9833 - val_loss: 0.0389 - val_accuracy: 0.9795
# Epoch 86/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0338 - accuracy: 0.9833 - val_loss: 0.0272 - val_accuracy: 0.9885
# Epoch 87/100
# 128/128 [==============================] - 3s 25ms/step - loss: 0.0344 - accuracy: 0.9830 - val_loss: 0.0262 - val_accuracy: 0.9885
# Epoch 88/100
# 128/128 [==============================] - 3s 21ms/step - loss: 0.0392 - accuracy: 0.9789 - val_loss: 0.0278 - val_accuracy: 0.9877
# Epoch 89/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0320 - accuracy: 0.9848 - val_loss: 0.0232 - val_accuracy: 0.9910
# Epoch 90/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0330 - accuracy: 0.9838 - val_loss: 0.0293 - val_accuracy: 0.9869
# Epoch 91/100
# 128/128 [==============================] - 2s 17ms/step - loss: 0.0359 - accuracy: 0.9816 - val_loss: 0.0365 - val_accuracy: 0.9795
# Epoch 92/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0338 - accuracy: 0.9828 - val_loss: 0.0253 - val_accuracy: 0.9894
# Epoch 93/100
# 128/128 [==============================] - 3s 25ms/step - loss: 0.0309 - accuracy: 0.9852 - val_loss: 0.0291 - val_accuracy: 0.9861
# Epoch 94/100
# 128/128 [==============================] - 2s 19ms/step - loss: 0.0330 - accuracy: 0.9833 - val_loss: 0.0345 - val_accuracy: 0.9812
# Epoch 95/100
# 128/128 [==============================] - 3s 20ms/step - loss: 0.0696 - accuracy: 0.9582 - val_loss: 0.0333 - val_accuracy: 0.9820
# Epoch 96/100
# 128/128 [==============================] - 3s 26ms/step - loss: 0.0358 - accuracy: 0.9821 - val_loss: 0.0257 - val_accuracy: 0.9894
# Epoch 97/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0321 - accuracy: 0.9843 - val_loss: 0.0229 - val_accuracy: 0.9902
# Epoch 98/100
# 128/128 [==============================] - 3s 24ms/step - loss: 0.0315 - accuracy: 0.9848 - val_loss: 0.0216 - val_accuracy: 0.9918
# Epoch 99/100
# 128/128 [==============================] - 3s 23ms/step - loss: 0.0290 - accuracy: 0.9862 - val_loss: 0.0231 - val_accuracy: 0.9902
# Epoch 100/100
# 128/128 [==============================] - 2s 18ms/step - loss: 0.0261 - accuracy: 0.9889 - val_loss: 0.0216 - val_accuracy: 0.9918

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score

predy=model.predict(testX)
predy=np.argmax(predy, axis=-1)
LABELS = ['SITTING','STANDIND','LAYING']
cm=confusion_matrix(testy,predy)
print(cm)
print(accuracy_score(testy,predy))
print(f1_score(testy,predy, average='weighted'))
print(classification_report(testy,predy))
sns.heatmap(cm, cmap="YlGnBu", xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt = '.2f')
# Out:
# 49/49 [==============================] - 0s 6ms/step
# [[415  71   5]
#  [ 16 516   0]
#  [  0   0 537]]
# 0.941025641025641
# 0.9404847192936066
#               precision    recall  f1-score   support
#
#            0       0.96      0.85      0.90       491
#            1       0.88      0.97      0.92       532
#            2       0.99      1.00      1.00       537
#
#     accuracy                           0.94      1560
#    macro avg       0.94      0.94      0.94      1560
# weighted avg       0.94      0.94      0.94      1560
# <Axes: >
